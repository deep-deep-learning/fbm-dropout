# %%
import torch.nn as nn
import torch.nn.functional as F
from fbm_dropout.fbm_dropout import DropoutFBM_2, DropoutFBM_3

# %%
dropout = DropoutFBM_2(0.9, 1, 3, (8, 8), show=True)

# %%
import torch
a = torch.rand((64))
for _ in range(3):
    dropout(a)
dropout.get_samples()
for _ in range(3):
    dropout(a)

# %%
dropout = DropoutFBM_3(0.9, 1, (8, 8), show=True)

# %%
dropout.agents_x[0][-1]
# Out:
# 0.1506088376045227

# %%
a = torch.rand((64))
for _ in range(10):
    dropout(a)
