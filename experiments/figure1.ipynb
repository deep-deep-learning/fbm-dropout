# %%
from fbm_dropout.fbm_dropout import DropoutFBM
import torch

# %%
dropout = DropoutFBM(hurst=0.9, n_agents=1, n_samples=50, max_iters=300, t_scale=10.0, grid_size=(10, 10))
a = torch.randn((10*10,))

for i in range(1, 301):
    out = dropout(a)
    if i == 1 or i % (300 / 2) == 0:
        title = 'figure_1_iter_{}.tif'.format(i)
        dropout.show_grid(title, 300, show_history=True)
