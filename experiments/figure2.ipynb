# %%
from fbm_dropout.fbm_dropout import DropoutFBM
import torch

# %%
dropout = DropoutFBM(hurst=0.9, n_agents=20, n_samples=50, max_iters=300, t_scale=10.0, grid_size=(10, 10))
a = torch.randn((10*10,))

for i in range(1, 301):
    out = dropout(a)
    if i % (300 / 4) == 0:
        title = 'figure_2_iter_{}.tif'.format(i)
        dropout.show_grid(title)
