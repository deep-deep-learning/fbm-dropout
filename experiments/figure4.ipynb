# %%
import torch
from fbm_dropout.dataset import get_MNIST_dataset

trainset, testset = get_MNIST_dataset('~/dataset')
idx = torch.randint(0, 60000, (1000,)).tolist()
trainset = torch.utils.data.Subset(trainset, idx)
idx = torch.randint(0, 10000, (1000,)).tolist()
testset = torch.utils.data.Subset(testset, idx)
batch_size = 64
train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=True)

# %%
from fbm_dropout.net import DenseNet, DenseNetFBM
import torch.optim as optim
import torch.nn as nn

hidden_sizes = [1024, 1024]
grid_sizes = [(32,32), (32,32)]
n_agents = [60, 60]

device='cuda'

model = DenseNet(hidden_sizes, [0, 0], device=device)
optimizer = optim.Adam(model.parameters(), lr=0.0001)

model_dropout = DenseNet(hidden_sizes, [.2, .2], device=device)
optimizer_dropout = optim.Adam(model_dropout.parameters(), lr=0.0001)

max_iters = len(train_loader)
model_fbm_dropout = DenseNetFBM(hidden_sizes, n_agents, 50, max_iters, 10, grid_sizes, device=device)
optimizer_fbm_dropout = optim.Adam(model_fbm_dropout.parameters(), lr=0.0001)

criterion = nn.CrossEntropyLoss()

# %%
results = {}
results['train loss'] = {}
results['train loss']['no dropout'] = []
results['train loss']['dropout'] = []
results['train loss']['fbm dropout'] = []

results['test loss'] = {}
results['test loss']['no dropout'] = []
results['test loss']['dropout'] = []
results['test loss']['fbm dropout'] = []

results['test acc'] = {}
results['test acc']['no dropout'] = []
results['test acc']['dropout'] = []
results['test acc']['fbm dropout'] = []

results['num wrong'] = {}
results['num wrong']['no dropout'] = []
results['num wrong']['dropout'] = []
results['num wrong']['fbm dropout'] = []

for epoch in range(100):
    model.train()
    model_dropout.train()
    model_fbm_dropout.train()

    running_loss = {}
    running_loss['no dropout'] = running_loss['dropout'] = running_loss['fbm dropout'] = 0.0
    for images, labels in train_loader:

        images = images.view(images.shape[0], -1).to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        optimizer_dropout.zero_grad()
        optimizer_fbm_dropout.zero_grad()

        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        running_loss['no dropout'] += loss.item()

        output_dropout = model_dropout(images)
        loss_dropout = criterion(output_dropout, labels)
        loss_dropout.backward()
        optimizer_dropout.step()
        running_loss['dropout'] += loss_dropout.item()

        output_fbm_dropout = model_fbm_dropout(images)
        loss_fbm_dropout = criterion(output_fbm_dropout, labels)
        loss_fbm_dropout.backward()
        optimizer_fbm_dropout.step()
        running_loss['fbm dropout'] += loss_fbm_dropout.item()

    results['train loss']['no dropout'].append(running_loss['no dropout'] / len(train_loader))
    results['train loss']['dropout'].append(running_loss['dropout'] / len(train_loader))
    results['train loss']['fbm dropout'].append(running_loss['fbm dropout'] / len(train_loader))

    model.eval()
    model_dropout.eval()
    model_fbm_dropout.eval()
    acc = acc_dropout = acc_fbm_dropout = 0.0
    running_loss['no dropout'] = running_loss['dropout'] = running_loss['fbm dropout'] = 0.0
    results['num wrong']['no dropout'].append(0)
    results['num wrong']['dropout'].append(0)
    results['num wrong']['fbm dropout'].append(0)
    for images, labels in test_loader:
        images = images.view(-1,784).to(device)
        labels = labels.to(device)
        output = model(images)
        _, pred = torch.max(output, axis=1)
        acc += torch.sum(pred==labels).item()
        running_loss['no dropout'] += criterion(output, labels).item()
        results['num wrong']['no dropout'][-1] += torch.sum(pred!=labels).item()
    

        output_dropout = model_dropout(images)
        _, pred_dropout = torch.max(output_dropout, axis=1)
        acc_dropout += torch.sum(pred_dropout==labels).item()
        running_loss['dropout'] += criterion(output_dropout, labels).item()
        results['num wrong']['dropout'][-1] += torch.sum(pred_dropout!=labels).item()
    
        output_fbm_dropout = model_fbm_dropout(images)
        _, pred_fbm_dropout = torch.max(output_fbm_dropout, axis=1)
        acc_fbm_dropout += torch.sum(pred_fbm_dropout==labels).item()
        running_loss['fbm dropout'] += criterion(output_fbm_dropout, labels).item()
        results['num wrong']['fbm dropout'][-1] += torch.sum(pred_fbm_dropout!=labels).item()
        
    results['test loss']['no dropout'].append(running_loss['no dropout'] / len(train_loader))
    results['test loss']['dropout'].append(running_loss['dropout'] / len(train_loader))
    results['test loss']['fbm dropout'].append(running_loss['fbm dropout'] / len(train_loader))
    
    results['test acc']['no dropout'].append(acc / len(testset))
    results['test acc']['dropout'].append(acc_dropout / len(testset))
    results['test acc']['fbm dropout'].append(acc_fbm_dropout / len(testset))

    model_fbm_dropout.dropout_1.branch_off()
    model_fbm_dropout.dropout_2.branch_off()
    
    print('Epoch {}'.format(epoch))
    print('No Dropout : Train Loss {:.4f}, Test Acc {:.4f}'.format(results['train loss']['no dropout'][-1], results['test acc']['no dropout'][-1]))
    print('Dropout    : Train Loss {:.4f}, Test Acc {:.4f}'.format(results['train loss']['dropout'][-1], results['test acc']['dropout'][-1]))
    print('FBM Dropout: Train Loss {:.4f}, Test Acc {:.4f}, Drop Rate {:.4f} {:.4f}'.format(results['train loss']['fbm dropout'][-1], 
                                                                                        results['test acc']['fbm dropout'][-1], 
                                                                                        model_fbm_dropout.dropout_1.cum_dropout_rate, 
                                                                                        model_fbm_dropout.dropout_2.cum_dropout_rate))
# Out:
# Epoch 0
# No Dropout : Train Loss 2.0780, Test Acc 0.5460
# Dropout    : Train Loss 2.1308, Test Acc 0.4350
# FBM Dropout: Train Loss 2.1485, Test Acc 0.4310, Drop Rate 0.2076 0.2088
# Epoch 1
# No Dropout : Train Loss 1.5562, Test Acc 0.6670
# Dropout    : Train Loss 1.6991, Test Acc 0.6220
# FBM Dropout: Train Loss 1.7716, Test Acc 0.6090, Drop Rate 0.2057 0.2099
# Epoch 2
# No Dropout : Train Loss 1.0639, Test Acc 0.7140
# Dropout    : Train Loss 1.2290, Test Acc 0.7100
# FBM Dropout: Train Loss 1.3589, Test Acc 0.6990, Drop Rate 0.2065 0.2093
# Epoch 3
# No Dropout : Train Loss 0.7615, Test Acc 0.7870
# Dropout    : Train Loss 0.8918, Test Acc 0.7920
# FBM Dropout: Train Loss 1.0216, Test Acc 0.7660, Drop Rate 0.2085 0.2077
# Epoch 4
# No Dropout : Train Loss 0.5842, Test Acc 0.8230
# Dropout    : Train Loss 0.6975, Test Acc 0.8300
# FBM Dropout: Train Loss 0.8024, Test Acc 0.8210, Drop Rate 0.2078 0.2085
# Epoch 5
# No Dropout : Train Loss 0.4772, Test Acc 0.8590
# Dropout    : Train Loss 0.5744, Test Acc 0.8510
# FBM Dropout: Train Loss 0.6670, Test Acc 0.8390, Drop Rate 0.2076 0.2094
# Epoch 6
# No Dropout : Train Loss 0.4258, Test Acc 0.8720
# Dropout    : Train Loss 0.5084, Test Acc 0.8570
# FBM Dropout: Train Loss 0.5958, Test Acc 0.8400, Drop Rate 0.2066 0.2089
# Epoch 7
# No Dropout : Train Loss 0.3720, Test Acc 0.8590
# Dropout    : Train Loss 0.4416, Test Acc 0.8570
# FBM Dropout: Train Loss 0.5325, Test Acc 0.8230, Drop Rate 0.2083 0.2087
# Epoch 8
# No Dropout : Train Loss 0.3556, Test Acc 0.8840
# Dropout    : Train Loss 0.4157, Test Acc 0.8780
# FBM Dropout: Train Loss 0.4979, Test Acc 0.8540, Drop Rate 0.2074 0.2088
# Epoch 9
# No Dropout : Train Loss 0.2992, Test Acc 0.8830
# Dropout    : Train Loss 0.3793, Test Acc 0.8820
# FBM Dropout: Train Loss 0.4368, Test Acc 0.8620, Drop Rate 0.2075 0.2091
# Epoch 10
# No Dropout : Train Loss 0.2767, Test Acc 0.8900
# Dropout    : Train Loss 0.3511, Test Acc 0.8770
# FBM Dropout: Train Loss 0.3962, Test Acc 0.8670, Drop Rate 0.2075 0.2088
# Epoch 11
# No Dropout : Train Loss 0.2523, Test Acc 0.8800
# Dropout    : Train Loss 0.3198, Test Acc 0.8760
# FBM Dropout: Train Loss 0.3564, Test Acc 0.8550, Drop Rate 0.2072 0.2090
# Epoch 12
# No Dropout : Train Loss 0.2337, Test Acc 0.8850
# Dropout    : Train Loss 0.3070, Test Acc 0.8850
# FBM Dropout: Train Loss 0.3207, Test Acc 0.8850, Drop Rate 0.2073 0.2084
# Epoch 13
# No Dropout : Train Loss 0.2108, Test Acc 0.8690
# Dropout    : Train Loss 0.2645, Test Acc 0.8710
# FBM Dropout: Train Loss 0.3208, Test Acc 0.8790, Drop Rate 0.2079 0.2084
# Epoch 14
# No Dropout : Train Loss 0.1922, Test Acc 0.8860
# Dropout    : Train Loss 0.2587, Test Acc 0.8840
# FBM Dropout: Train Loss 0.2838, Test Acc 0.8840, Drop Rate 0.2080 0.2079
# Epoch 15
# No Dropout : Train Loss 0.1792, Test Acc 0.8870
# Dropout    : Train Loss 0.2343, Test Acc 0.8830
# FBM Dropout: Train Loss 0.2982, Test Acc 0.8770, Drop Rate 0.2080 0.2073
# Epoch 16
# No Dropout : Train Loss 0.1656, Test Acc 0.8810
# Dropout    : Train Loss 0.2202, Test Acc 0.8820
# FBM Dropout: Train Loss 0.2758, Test Acc 0.8600, Drop Rate 0.2082 0.2070
# Epoch 17
# No Dropout : Train Loss 0.1483, Test Acc 0.8860
# Dropout    : Train Loss 0.2053, Test Acc 0.8840
# FBM Dropout: Train Loss 0.2806, Test Acc 0.8810, Drop Rate 0.2081 0.2064
# Epoch 18
# No Dropout : Train Loss 0.1378, Test Acc 0.8950
# Dropout    : Train Loss 0.1973, Test Acc 0.8940
# FBM Dropout: Train Loss 0.2399, Test Acc 0.8900, Drop Rate 0.2080 0.2064
# Epoch 19
# No Dropout : Train Loss 0.1264, Test Acc 0.8860
# Dropout    : Train Loss 0.1903, Test Acc 0.8880
# FBM Dropout: Train Loss 0.2331, Test Acc 0.8900, Drop Rate 0.2079 0.2061
# Epoch 20
# No Dropout : Train Loss 0.1186, Test Acc 0.8980
# Dropout    : Train Loss 0.1827, Test Acc 0.8950
# FBM Dropout: Train Loss 0.2078, Test Acc 0.8950, Drop Rate 0.2078 0.2060
# Epoch 21
# No Dropout : Train Loss 0.1079, Test Acc 0.8880
# Dropout    : Train Loss 0.1581, Test Acc 0.8890
# FBM Dropout: Train Loss 0.2134, Test Acc 0.8800, Drop Rate 0.2080 0.2058
# Epoch 22
# No Dropout : Train Loss 0.1071, Test Acc 0.8970
# Dropout    : Train Loss 0.1571, Test Acc 0.9000
# FBM Dropout: Train Loss 0.1992, Test Acc 0.8950, Drop Rate 0.2079 0.2061
# Epoch 23
# No Dropout : Train Loss 0.0877, Test Acc 0.8950
# Dropout    : Train Loss 0.1474, Test Acc 0.8880
# FBM Dropout: Train Loss 0.1707, Test Acc 0.8630, Drop Rate 0.2082 0.2061
# Epoch 24
# No Dropout : Train Loss 0.0855, Test Acc 0.8960
# Dropout    : Train Loss 0.1433, Test Acc 0.8890
# FBM Dropout: Train Loss 0.1679, Test Acc 0.8870, Drop Rate 0.2081 0.2060
# Epoch 25
# No Dropout : Train Loss 0.0821, Test Acc 0.8880
# Dropout    : Train Loss 0.1260, Test Acc 0.8780
# FBM Dropout: Train Loss 0.1669, Test Acc 0.8820, Drop Rate 0.2079 0.2061
# Epoch 26
# No Dropout : Train Loss 0.0710, Test Acc 0.9050
# Dropout    : Train Loss 0.1225, Test Acc 0.8980
# FBM Dropout: Train Loss 0.1439, Test Acc 0.8950, Drop Rate 0.2077 0.2061
# Epoch 27
# No Dropout : Train Loss 0.0666, Test Acc 0.8940
# Dropout    : Train Loss 0.1075, Test Acc 0.8940
# FBM Dropout: Train Loss 0.1495, Test Acc 0.8730, Drop Rate 0.2075 0.2061
# Epoch 28
# No Dropout : Train Loss 0.0625, Test Acc 0.9000
# Dropout    : Train Loss 0.1060, Test Acc 0.8980
# FBM Dropout: Train Loss 0.1359, Test Acc 0.8940, Drop Rate 0.2075 0.2062
# Epoch 29
# No Dropout : Train Loss 0.0571, Test Acc 0.8900
# Dropout    : Train Loss 0.1040, Test Acc 0.8920
# FBM Dropout: Train Loss 0.1337, Test Acc 0.8850, Drop Rate 0.2072 0.2061
# Epoch 30
# No Dropout : Train Loss 0.0510, Test Acc 0.8780
# Dropout    : Train Loss 0.0987, Test Acc 0.8790
# FBM Dropout: Train Loss 0.1142, Test Acc 0.8890, Drop Rate 0.2072 0.2062
# Epoch 31
# No Dropout : Train Loss 0.0489, Test Acc 0.8970
# Dropout    : Train Loss 0.0931, Test Acc 0.8910
# FBM Dropout: Train Loss 0.1339, Test Acc 0.8860, Drop Rate 0.2071 0.2061
# Epoch 32
# No Dropout : Train Loss 0.0437, Test Acc 0.8980
# Dropout    : Train Loss 0.0785, Test Acc 0.8960
# FBM Dropout: Train Loss 0.1218, Test Acc 0.8880, Drop Rate 0.2072 0.2061
# Epoch 33
# No Dropout : Train Loss 0.0401, Test Acc 0.8870
# Dropout    : Train Loss 0.0812, Test Acc 0.8940
# FBM Dropout: Train Loss 0.1050, Test Acc 0.8900, Drop Rate 0.2076 0.2064
# Epoch 34
# No Dropout : Train Loss 0.0362, Test Acc 0.8960
# Dropout    : Train Loss 0.0718, Test Acc 0.8990
# FBM Dropout: Train Loss 0.0908, Test Acc 0.8960, Drop Rate 0.2074 0.2064
# Epoch 35
# No Dropout : Train Loss 0.0343, Test Acc 0.8960
# Dropout    : Train Loss 0.0688, Test Acc 0.8990
# FBM Dropout: Train Loss 0.0968, Test Acc 0.8970, Drop Rate 0.2074 0.2065
# Epoch 36
# No Dropout : Train Loss 0.0326, Test Acc 0.8960
# Dropout    : Train Loss 0.0601, Test Acc 0.8930
# FBM Dropout: Train Loss 0.0820, Test Acc 0.8870, Drop Rate 0.2077 0.2066
# Epoch 37
# No Dropout : Train Loss 0.0307, Test Acc 0.8910
# Dropout    : Train Loss 0.0604, Test Acc 0.8940
# FBM Dropout: Train Loss 0.0808, Test Acc 0.8990, Drop Rate 0.2076 0.2067
# Epoch 38
# No Dropout : Train Loss 0.0276, Test Acc 0.8960
# Dropout    : Train Loss 0.0530, Test Acc 0.8990
# FBM Dropout: Train Loss 0.0756, Test Acc 0.8980, Drop Rate 0.2075 0.2069
# Epoch 39
# No Dropout : Train Loss 0.0251, Test Acc 0.9010
# Dropout    : Train Loss 0.0595, Test Acc 0.8990
# FBM Dropout: Train Loss 0.0805, Test Acc 0.8950, Drop Rate 0.2074 0.2067
# Epoch 40
# No Dropout : Train Loss 0.0234, Test Acc 0.8920
# Dropout    : Train Loss 0.0488, Test Acc 0.8920
# FBM Dropout: Train Loss 0.0711, Test Acc 0.8800, Drop Rate 0.2075 0.2067
# Epoch 41
# No Dropout : Train Loss 0.0220, Test Acc 0.9010
# Dropout    : Train Loss 0.0498, Test Acc 0.8920
# FBM Dropout: Train Loss 0.0685, Test Acc 0.8960, Drop Rate 0.2073 0.2066
# Epoch 42
# No Dropout : Train Loss 0.0203, Test Acc 0.8990
# Dropout    : Train Loss 0.0435, Test Acc 0.8950
# FBM Dropout: Train Loss 0.0616, Test Acc 0.8990, Drop Rate 0.2073 0.2064
# Epoch 43
# No Dropout : Train Loss 0.0197, Test Acc 0.8980
# Dropout    : Train Loss 0.0455, Test Acc 0.8980
# FBM Dropout: Train Loss 0.0553, Test Acc 0.8980, Drop Rate 0.2071 0.2065
# Epoch 44
# No Dropout : Train Loss 0.0188, Test Acc 0.8940
# Dropout    : Train Loss 0.0439, Test Acc 0.9010
# FBM Dropout: Train Loss 0.0499, Test Acc 0.8990, Drop Rate 0.2072 0.2065
# Epoch 45
# No Dropout : Train Loss 0.0188, Test Acc 0.8950
# Dropout    : Train Loss 0.0385, Test Acc 0.8920
# FBM Dropout: Train Loss 0.0497, Test Acc 0.8870, Drop Rate 0.2071 0.2064
# Epoch 46
# No Dropout : Train Loss 0.0163, Test Acc 0.9000
# Dropout    : Train Loss 0.0375, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0459, Test Acc 0.8950, Drop Rate 0.2073 0.2065
# Epoch 47
# No Dropout : Train Loss 0.0153, Test Acc 0.9010
# Dropout    : Train Loss 0.0390, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0459, Test Acc 0.8960, Drop Rate 0.2072 0.2066
# Epoch 48
# No Dropout : Train Loss 0.0154, Test Acc 0.8960
# Dropout    : Train Loss 0.0324, Test Acc 0.8960
# FBM Dropout: Train Loss 0.0391, Test Acc 0.8940, Drop Rate 0.2072 0.2065
# Epoch 49
# No Dropout : Train Loss 0.0143, Test Acc 0.8980
# Dropout    : Train Loss 0.0297, Test Acc 0.8980
# FBM Dropout: Train Loss 0.0489, Test Acc 0.9010, Drop Rate 0.2072 0.2064
# Epoch 50
# No Dropout : Train Loss 0.0128, Test Acc 0.8990
# Dropout    : Train Loss 0.0311, Test Acc 0.8820
# FBM Dropout: Train Loss 0.0404, Test Acc 0.8980, Drop Rate 0.2072 0.2065
# Epoch 51
# No Dropout : Train Loss 0.0121, Test Acc 0.8960
# Dropout    : Train Loss 0.0287, Test Acc 0.8930
# FBM Dropout: Train Loss 0.0393, Test Acc 0.8900, Drop Rate 0.2072 0.2064
# Epoch 52
# No Dropout : Train Loss 0.0116, Test Acc 0.8960
# Dropout    : Train Loss 0.0265, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0366, Test Acc 0.9000, Drop Rate 0.2072 0.2066
# Epoch 53
# No Dropout : Train Loss 0.0113, Test Acc 0.8990
# Dropout    : Train Loss 0.0255, Test Acc 0.8940
# FBM Dropout: Train Loss 0.0398, Test Acc 0.9010, Drop Rate 0.2073 0.2066
# Epoch 54
# No Dropout : Train Loss 0.0107, Test Acc 0.9000
# Dropout    : Train Loss 0.0253, Test Acc 0.8900
# FBM Dropout: Train Loss 0.0372, Test Acc 0.8940, Drop Rate 0.2074 0.2067
# Epoch 55
# No Dropout : Train Loss 0.0098, Test Acc 0.8980
# Dropout    : Train Loss 0.0200, Test Acc 0.8910
# FBM Dropout: Train Loss 0.0314, Test Acc 0.9000, Drop Rate 0.2075 0.2067
# Epoch 56
# No Dropout : Train Loss 0.0094, Test Acc 0.9000
# Dropout    : Train Loss 0.0211, Test Acc 0.8980
# FBM Dropout: Train Loss 0.0367, Test Acc 0.9000, Drop Rate 0.2075 0.2068
# Epoch 57
# No Dropout : Train Loss 0.0091, Test Acc 0.9040
# Dropout    : Train Loss 0.0191, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0372, Test Acc 0.9020, Drop Rate 0.2073 0.2068
# Epoch 58
# No Dropout : Train Loss 0.0091, Test Acc 0.8960
# Dropout    : Train Loss 0.0168, Test Acc 0.8960
# FBM Dropout: Train Loss 0.0311, Test Acc 0.8980, Drop Rate 0.2073 0.2069
# Epoch 59
# No Dropout : Train Loss 0.0090, Test Acc 0.9030
# Dropout    : Train Loss 0.0178, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0269, Test Acc 0.9020, Drop Rate 0.2072 0.2069
# Epoch 60
# No Dropout : Train Loss 0.0081, Test Acc 0.8950
# Dropout    : Train Loss 0.0149, Test Acc 0.8980
# FBM Dropout: Train Loss 0.0252, Test Acc 0.8890, Drop Rate 0.2071 0.2068
# Epoch 61
# No Dropout : Train Loss 0.0078, Test Acc 0.8980
# Dropout    : Train Loss 0.0145, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0281, Test Acc 0.9000, Drop Rate 0.2071 0.2068
# Epoch 62
# No Dropout : Train Loss 0.0075, Test Acc 0.9010
# Dropout    : Train Loss 0.0160, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0226, Test Acc 0.8960, Drop Rate 0.2072 0.2066
# Epoch 63
# No Dropout : Train Loss 0.0070, Test Acc 0.8950
# Dropout    : Train Loss 0.0141, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0258, Test Acc 0.9010, Drop Rate 0.2072 0.2066
# Epoch 64
# No Dropout : Train Loss 0.0069, Test Acc 0.8990
# Dropout    : Train Loss 0.0157, Test Acc 0.8940
# FBM Dropout: Train Loss 0.0278, Test Acc 0.8810, Drop Rate 0.2071 0.2065
# Epoch 65
# No Dropout : Train Loss 0.0064, Test Acc 0.9020
# Dropout    : Train Loss 0.0136, Test Acc 0.8930
# FBM Dropout: Train Loss 0.0248, Test Acc 0.9020, Drop Rate 0.2070 0.2065
# Epoch 66
# No Dropout : Train Loss 0.0061, Test Acc 0.8970
# Dropout    : Train Loss 0.0128, Test Acc 0.8970
# FBM Dropout: Train Loss 0.0229, Test Acc 0.9010, Drop Rate 0.2071 0.2065
# Epoch 67
# No Dropout : Train Loss 0.0060, Test Acc 0.8980
# Dropout    : Train Loss 0.0141, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0224, Test Acc 0.9020, Drop Rate 0.2071 0.2065
# Epoch 68
# No Dropout : Train Loss 0.0057, Test Acc 0.9010
# Dropout    : Train Loss 0.0147, Test Acc 0.8980
# FBM Dropout: Train Loss 0.0198, Test Acc 0.8990, Drop Rate 0.2070 0.2066
# Epoch 69
# No Dropout : Train Loss 0.0054, Test Acc 0.8970
# Dropout    : Train Loss 0.0137, Test Acc 0.8970
# FBM Dropout: Train Loss 0.0193, Test Acc 0.9040, Drop Rate 0.2070 0.2065
# Epoch 70
# No Dropout : Train Loss 0.0056, Test Acc 0.9010
# Dropout    : Train Loss 0.0112, Test Acc 0.9020
# FBM Dropout: Train Loss 0.0178, Test Acc 0.9050, Drop Rate 0.2071 0.2066
# Epoch 71
# No Dropout : Train Loss 0.0053, Test Acc 0.8990
# Dropout    : Train Loss 0.0126, Test Acc 0.8970
# FBM Dropout: Train Loss 0.0161, Test Acc 0.8980, Drop Rate 0.2070 0.2064
# Epoch 72
# No Dropout : Train Loss 0.0050, Test Acc 0.8990
# Dropout    : Train Loss 0.0116, Test Acc 0.8960
# FBM Dropout: Train Loss 0.0178, Test Acc 0.9050, Drop Rate 0.2070 0.2065
# Epoch 73
# No Dropout : Train Loss 0.0048, Test Acc 0.9010
# Dropout    : Train Loss 0.0137, Test Acc 0.8980
# FBM Dropout: Train Loss 0.0169, Test Acc 0.9050, Drop Rate 0.2070 0.2065
# Epoch 74
# No Dropout : Train Loss 0.0046, Test Acc 0.8980
# Dropout    : Train Loss 0.0099, Test Acc 0.9020
# FBM Dropout: Train Loss 0.0166, Test Acc 0.9040, Drop Rate 0.2070 0.2065
# Epoch 75
# No Dropout : Train Loss 0.0044, Test Acc 0.9010
# Dropout    : Train Loss 0.0107, Test Acc 0.9040
# FBM Dropout: Train Loss 0.0126, Test Acc 0.9030, Drop Rate 0.2070 0.2065
# Epoch 76
# No Dropout : Train Loss 0.0044, Test Acc 0.9000
# Dropout    : Train Loss 0.0104, Test Acc 0.8970
# FBM Dropout: Train Loss 0.0146, Test Acc 0.8970, Drop Rate 0.2071 0.2064
# Epoch 77
# No Dropout : Train Loss 0.0043, Test Acc 0.8980
# Dropout    : Train Loss 0.0079, Test Acc 0.8970
# FBM Dropout: Train Loss 0.0119, Test Acc 0.9080, Drop Rate 0.2071 0.2065
# Epoch 78
# No Dropout : Train Loss 0.0040, Test Acc 0.9030
# Dropout    : Train Loss 0.0097, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0102, Test Acc 0.9050, Drop Rate 0.2071 0.2064
# Epoch 79
# No Dropout : Train Loss 0.0039, Test Acc 0.8970
# Dropout    : Train Loss 0.0090, Test Acc 0.9020
# FBM Dropout: Train Loss 0.0134, Test Acc 0.9050, Drop Rate 0.2071 0.2065
# Epoch 80
# No Dropout : Train Loss 0.0038, Test Acc 0.9030
# Dropout    : Train Loss 0.0086, Test Acc 0.9010
# FBM Dropout: Train Loss 0.0127, Test Acc 0.9020, Drop Rate 0.2071 0.2065
# Epoch 81
# No Dropout : Train Loss 0.0036, Test Acc 0.8980
# Dropout    : Train Loss 0.0082, Test Acc 0.9030
# FBM Dropout: Train Loss 0.0097, Test Acc 0.9030, Drop Rate 0.2070 0.2066
# Epoch 82
# No Dropout : Train Loss 0.0036, Test Acc 0.9000
# Dropout    : Train Loss 0.0074, Test Acc 0.8980
# FBM Dropout: Train Loss 0.0101, Test Acc 0.9060, Drop Rate 0.2071 0.2066
# Epoch 83
# No Dropout : Train Loss 0.0036, Test Acc 0.9000
# Dropout    : Train Loss 0.0083, Test Acc 0.8990
# FBM Dropout: Train Loss 0.0106, Test Acc 0.9000, Drop Rate 0.2071 0.2067
# Epoch 84
# No Dropout : Train Loss 0.0034, Test Acc 0.9030
# Dropout    : Train Loss 0.0085, Test Acc 0.8910
# FBM Dropout: Train Loss 0.0106, Test Acc 0.9090, Drop Rate 0.2070 0.2066
# Epoch 85
# No Dropout : Train Loss 0.0032, Test Acc 0.8980
# Dropout    : Train Loss 0.0077, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0107, Test Acc 0.9030, Drop Rate 0.2070 0.2066
# Epoch 86
# No Dropout : Train Loss 0.0031, Test Acc 0.8990
# Dropout    : Train Loss 0.0063, Test Acc 0.9010
# FBM Dropout: Train Loss 0.0093, Test Acc 0.9030, Drop Rate 0.2070 0.2066
# Epoch 87
# No Dropout : Train Loss 0.0030, Test Acc 0.9000
# Dropout    : Train Loss 0.0069, Test Acc 0.9010
# FBM Dropout: Train Loss 0.0086, Test Acc 0.9060, Drop Rate 0.2071 0.2067
# Epoch 88
# No Dropout : Train Loss 0.0029, Test Acc 0.8990
# Dropout    : Train Loss 0.0066, Test Acc 0.8990
# FBM Dropout: Train Loss 0.0119, Test Acc 0.9010, Drop Rate 0.2071 0.2067
# Epoch 89
# No Dropout : Train Loss 0.0029, Test Acc 0.9000
# Dropout    : Train Loss 0.0059, Test Acc 0.9010
# FBM Dropout: Train Loss 0.0091, Test Acc 0.9070, Drop Rate 0.2071 0.2067
# Epoch 90
# No Dropout : Train Loss 0.0028, Test Acc 0.9010
# Dropout    : Train Loss 0.0063, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0080, Test Acc 0.9000, Drop Rate 0.2072 0.2067
# Epoch 91
# No Dropout : Train Loss 0.0027, Test Acc 0.8960
# Dropout    : Train Loss 0.0065, Test Acc 0.8970
# FBM Dropout: Train Loss 0.0103, Test Acc 0.9050, Drop Rate 0.2072 0.2066
# Epoch 92
# No Dropout : Train Loss 0.0027, Test Acc 0.9000
# Dropout    : Train Loss 0.0061, Test Acc 0.8980
# FBM Dropout: Train Loss 0.0085, Test Acc 0.9010, Drop Rate 0.2071 0.2066
# Epoch 93
# No Dropout : Train Loss 0.0025, Test Acc 0.8980
# Dropout    : Train Loss 0.0053, Test Acc 0.8980
# FBM Dropout: Train Loss 0.0088, Test Acc 0.9020, Drop Rate 0.2073 0.2066
# Epoch 94
# No Dropout : Train Loss 0.0025, Test Acc 0.9000
# Dropout    : Train Loss 0.0065, Test Acc 0.9000
# FBM Dropout: Train Loss 0.0092, Test Acc 0.9020, Drop Rate 0.2072 0.2065
# Epoch 95
# No Dropout : Train Loss 0.0025, Test Acc 0.9010
# Dropout    : Train Loss 0.0082, Test Acc 0.8960
# FBM Dropout: Train Loss 0.0085, Test Acc 0.9000, Drop Rate 0.2072 0.2065
# Epoch 96
# No Dropout : Train Loss 0.0023, Test Acc 0.8990
# Dropout    : Train Loss 0.0069, Test Acc 0.8980
# FBM Dropout: Train Loss 0.0093, Test Acc 0.9010, Drop Rate 0.2072 0.2065
# Epoch 97
# No Dropout : Train Loss 0.0023, Test Acc 0.9010
# Dropout    : Train Loss 0.0060, Test Acc 0.8970
# FBM Dropout: Train Loss 0.0076, Test Acc 0.9010, Drop Rate 0.2072 0.2064
# Epoch 98
# No Dropout : Train Loss 0.0023, Test Acc 0.9000
# Dropout    : Train Loss 0.0050, Test Acc 0.8960
# FBM Dropout: Train Loss 0.0057, Test Acc 0.9060, Drop Rate 0.2071 0.2065
# Epoch 99
# No Dropout : Train Loss 0.0022, Test Acc 0.8980
# Dropout    : Train Loss 0.0052, Test Acc 0.9030
# FBM Dropout: Train Loss 0.0087, Test Acc 0.9030, Drop Rate 0.2071 0.2065

# %%
import numpy as np

np.save('train_loss_no_dropout', results['train loss']['no dropout'])
np.save('train_loss_dropout', results['train loss']['dropout'])
np.save('train_loss_fbm_dropout', results['train loss']['fbm dropout'])

np.save('test_loss_no_dropout', results['test loss']['no dropout'])
np.save('test_loss_dropout', results['test loss']['dropout'])
np.save('test_loss_fbm_dropout', results['test loss']['fbm dropout'])

np.save('test_acc_no_dropout', results['test acc']['no dropout'])
np.save('test_acc_dropout', results['test acc']['dropout'])
np.save('test_acc_fbm_dropout', results['test acc']['fbm dropout'])

np.save('num_wrong_no_dropout', results['num wrong']['no dropout'])
np.save('num_wrong_dropout', results['num wrong']['dropout'])
np.save('num_wrong_fbm_dropout', results['num wrong']['fbm dropout'])

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6.4, 4.8), facecolor=(1,1,1))

ax.plot(results['train loss']['no dropout'], label='No Dropout', c='r')
ax.plot(results['train loss']['dropout'], label='Std. Dropout', c='g')
ax.plot(results['train loss']['fbm dropout'], label='FBM Dropout', c='b')
ax.set_ylim(0, 1)
ax.legend()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_ylabel('Test Loss')
ax.set_xlabel('Epoch')
plt.savefig('fig4_train_loss_1.tif', dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.4, 4.8), facecolor=(1,1,1))

ax.plot(results['train loss']['no dropout'], label='No Dropout', c='r')
ax.plot(results['train loss']['dropout'], label='Std. Dropout', c='g')
ax.plot(results['train loss']['fbm dropout'], label='FBM Dropout', c='b')
ax.set_ylim(0, 0.1)
ax.legend()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_ylabel('Train Loss')
ax.set_xlabel('Epoch')
plt.savefig('fig4_train_loss_2.tif', dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.4, 4.8), facecolor=(1,1,1))

ax.plot(results['test loss']['no dropout'], label='No Dropout', c='r')
ax.plot(results['test loss']['dropout'], label='Std. Dropout', c='g')
ax.plot(results['test loss']['fbm dropout'], label='FBM Dropout', c='b')

ax.set_ylim(0, 1)
ax.legend()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_ylabel('Test Loss')
ax.set_xlabel('Epoch')
plt.savefig('fig4_test_loss_1.tif', dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.4, 4.8), facecolor=(1,1,1))

ax.plot(results['test loss']['no dropout'], label='No Dropout', c='r')
ax.plot(results['test loss']['dropout'], label='Std. Dropout', c='g')
ax.plot(results['test loss']['fbm dropout'], label='FBM Dropout', c='b')
ax.set_ylim(0.3, 0.5)
ax.legend()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_ylabel('Test Loss')
ax.set_xlabel('Epoch')
plt.savefig('fig4_test_loss_2.tif', dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.4, 4.8), facecolor=(1,1,1))

ax.plot([x-y for x, y in zip(results['test loss']['no dropout'],results['train loss']['no dropout'])], label='No Dropout', c='r')
ax.plot([x-y for x, y in zip(results['test loss']['dropout'],results['train loss']['dropout'])], label='Std. Dropout', c='g')
ax.plot([x-y for x, y in zip(results['test loss']['fbm dropout'],results['train loss']['fbm dropout'])], label='FBM Dropout', c='b')
ax.set_ylabel('Generalization Gap')
ax.set_xlabel('Epoch')
ax.legend()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig('fig4_gen_gap_1.tif', dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.4, 4.8), facecolor=(1,1,1))

ax.plot(results['test acc']['no dropout'], label='No Dropout', c='r')
ax.plot(results['test acc']['dropout'], label='Std. Dropout', c='g')
ax.plot(results['test acc']['fbm dropout'], label='FBM Dropout', c='b')
ax.set_ylabel('Test Accuracy')
ax.set_xlabel('Epoch')
ax.legend()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig('fig4_test_acc_1.tif', dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.4, 4.8), facecolor=(1,1,1))

ax.plot(results['test acc']['no dropout'], label='No Dropout', c='r')
ax.plot(results['test acc']['dropout'], label='Std. Dropout', c='g')
ax.plot(results['test acc']['fbm dropout'], label='FBM Dropout', c='b')
ax.set_ylabel('Test Accuracy')
ax.set_xlabel('Epoch')
ax.legend()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_ylim(.85)
plt.savefig('fig4_test_acc_2.tif', dpi=300)
plt.show()
