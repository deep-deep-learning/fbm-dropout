# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch.nn as nn
import torch.nn.functional as F
from fbm_dropout.fbm_dropout import DropoutFBM

class DenseNetFBM(nn.Module):

    def __init__(self, hidden_sizes, n_agents, max_epoch, grid_sizes, device=None, dtype=None):

        super().__init__()
        
        self.linear_1 = nn.Linear(28*28, hidden_sizes[0], device=device, dtype=dtype)
        self.linear_2 = nn.Linear(hidden_sizes[0], hidden_sizes[1], device=device, dtype=dtype)
        self.linear_3 = nn.Linear(hidden_sizes[1], 10, device=device, dtype=dtype)
        self.dropout_1 = DropoutFBM(0.9, n_agents[0], max_epoch, grid_sizes[0], show=False, device=device, dtype=dtype)
        self.dropout_2 = DropoutFBM(0.9, n_agents[1], max_epoch, grid_sizes[1], show=False, device=device, dtype=dtype)

    def forward(self, input, current_epoch):

        if self.training:
            output = F.relu(self.dropout_1(self.linear_1(input), current_epoch))
            output = F.relu(self.dropout_2(self.linear_2(output), current_epoch))
        else:
            output = F.relu(self.linear_1(input))
            output = F.relu(self.linear_2(output))
            
        output = self.linear_3(output)
        
        return output

# %%
import torch.nn as nn
import torch.nn.functional as F

class DenseNet(nn.Module):

    def __init__(self, hidden_sizes, dropout_rate, device=None, dtype=None):

        super().__init__()
        
        self.linear_1 = nn.Linear(784, hidden_sizes[0], device=device, dtype=dtype)
        self.linear_2 = nn.Linear(hidden_sizes[0], hidden_sizes[1], device=device, dtype=dtype)
        self.linear_3 = nn.Linear(hidden_sizes[1], 10, device=device, dtype=dtype)
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, input):

        output = F.relu(self.dropout(self.linear_1(input)))
        output = F.relu(self.dropout(self.linear_2(output)))
        output = self.linear_3(output)
        return output

# %%
from torchvision import datasets, transforms
import torch

transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),])

trainset = datasets.MNIST('~/datasets', download=True, train=True, transform=transform)
train_loader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = datasets.MNIST('~/datasets', download=True, train=False, transform=transform)
test_loader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# %%
import torch.optim as optim

hidden_sizes = [256, 64]
max_epochs = 200
grid_sizes = [(16,16), (8,8)]
n_agents = [128, 32]
device='cuda'

model = DenseNet(hidden_sizes, 0, device=device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

model_dropout = DenseNet(hidden_sizes, .2, device=device)
optimizer_dropout = optim.Adam(model_dropout.parameters(), lr=0.001)

model_fbm_dropout = DenseNetFBM(hidden_sizes, n_agents, max_epochs, grid_sizes, device=device)
optimizer_fbm_dropout = optim.Adam(model_fbm_dropout.parameters(), lr=0.001)

criterion = nn.CrossEntropyLoss()

# %%
results = {}
results['train loss'] = {}
results['train loss']['no dropout'] = []
results['train loss']['dropout'] = []
results['train loss']['fbm dropout'] = []
results['test acc'] = {}
results['test acc']['no dropout'] = []
results['test acc']['dropout'] = []
results['test acc']['fbm dropout'] = []
for epoch in range(max_epochs):
    model.train()
    model_dropout.train()
    model_fbm_dropout.train()

    running_loss = {}
    running_loss['no dropout'] = running_loss['dropout'] = running_loss['fbm dropout'] = 0.0
    for images, labels in train_loader:

        images = images.view(images.shape[0], -1).to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        optimizer_dropout.zero_grad()
        optimizer_fbm_dropout.zero_grad()

        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        running_loss['no dropout'] += loss.item()

        output_dropout = model_dropout(images)
        loss_dropout = criterion(output_dropout, labels)
        loss_dropout.backward()
        optimizer_dropout.step()
        running_loss['dropout'] += loss_dropout.item()

        output_fbm_dropout = model_fbm_dropout(images, epoch)
        loss_fbm_dropout = criterion(output_fbm_dropout, labels)
        loss_fbm_dropout.backward()
        optimizer_fbm_dropout.step()
        running_loss['fbm dropout'] += loss_fbm_dropout.item()

    results['train loss']['no dropout'].append(running_loss['no dropout'] / len(train_loader))
    results['train loss']['dropout'].append(running_loss['dropout'] / len(train_loader))
    results['train loss']['fbm dropout'].append(running_loss['fbm dropout'] / len(train_loader))

    model.eval()
    model_dropout.eval()
    model_fbm_dropout.eval()
    acc = acc_dropout = acc_fbm_dropout = 0.0
    for images, labels in test_loader:
        images = images.view(-1,784).to(device)
        labels = labels.to(device)
        output = model(images)
        _, pred = torch.max(output, axis=1)
        acc += torch.sum(pred==labels).item()

        output_dropout = model_dropout(images)
        _, pred_dropout = torch.max(output_dropout, axis=1)
        acc_dropout += torch.sum(pred_dropout==labels).item()

        output_fbm_dropout = model_fbm_dropout(images, epoch)
        _, pred_fbm_dropout = torch.max(output_fbm_dropout, axis=1)
        acc_fbm_dropout += torch.sum(pred_fbm_dropout==labels).item()
    
    results['test acc']['no dropout'].append(acc / len(testset))
    results['test acc']['dropout'].append(acc_dropout / len(testset))
    results['test acc']['fbm dropout'].append(acc_fbm_dropout / len(testset))

    
    print('Epoch {}'.format(epoch))
    print('No Dropout : Train Loss {:.2f}, Test Acc {:.2f}'.format(results['train loss']['no dropout'][-1], results['test acc']['no dropout'][-1]))
    print('Dropout    : Train Loss {:.2f}, Test Acc {:.2f}'.format(results['train loss']['dropout'][-1], results['test acc']['dropout'][-1]))
    print('FBM Dropout: Train Loss {:.2f}, Test Acc {:.2f}'.format(results['train loss']['fbm dropout'][-1], results['test acc']['fbm dropout'][-1]))
# Out:
# Epoch 0
# No Dropout : Train Loss 0.36, Test Acc 0.94
# Dropout    : Train Loss 0.42, Test Acc 0.94
# FBM Dropout: Train Loss 0.39, Test Acc 0.93
# Epoch 1
# No Dropout : Train Loss 0.16, Test Acc 0.96
# Dropout    : Train Loss 0.22, Test Acc 0.96
# FBM Dropout: Train Loss 0.18, Test Acc 0.94
# Epoch 2
# No Dropout : Train Loss 0.12, Test Acc 0.96
# Dropout    : Train Loss 0.17, Test Acc 0.96
# FBM Dropout: Train Loss 0.13, Test Acc 0.96
# Epoch 3
# No Dropout : Train Loss 0.09, Test Acc 0.97
# Dropout    : Train Loss 0.15, Test Acc 0.97
# FBM Dropout: Train Loss 0.11, Test Acc 0.95
# Epoch 4
# No Dropout : Train Loss 0.08, Test Acc 0.97
# Dropout    : Train Loss 0.14, Test Acc 0.97
# FBM Dropout: Train Loss 0.09, Test Acc 0.96
# Epoch 5
# No Dropout : Train Loss 0.07, Test Acc 0.97
# Dropout    : Train Loss 0.13, Test Acc 0.97
# FBM Dropout: Train Loss 0.08, Test Acc 0.96
# Epoch 6
# No Dropout : Train Loss 0.06, Test Acc 0.97
# Dropout    : Train Loss 0.12, Test Acc 0.97
# FBM Dropout: Train Loss 0.07, Test Acc 0.96
# Epoch 7
# No Dropout : Train Loss 0.05, Test Acc 0.97
# Dropout    : Train Loss 0.11, Test Acc 0.97
# FBM Dropout: Train Loss 0.06, Test Acc 0.96
# Epoch 8
# No Dropout : Train Loss 0.05, Test Acc 0.97
# Dropout    : Train Loss 0.10, Test Acc 0.97
# FBM Dropout: Train Loss 0.06, Test Acc 0.97
# Epoch 9
# No Dropout : Train Loss 0.05, Test Acc 0.98
# Dropout    : Train Loss 0.10, Test Acc 0.98
# FBM Dropout: Train Loss 0.06, Test Acc 0.97
# Epoch 10
# No Dropout : Train Loss 0.04, Test Acc 0.98
# Dropout    : Train Loss 0.10, Test Acc 0.97
# FBM Dropout: Train Loss 0.05, Test Acc 0.97
# Epoch 11
# No Dropout : Train Loss 0.04, Test Acc 0.98
# Dropout    : Train Loss 0.09, Test Acc 0.97
# FBM Dropout: Train Loss 0.05, Test Acc 0.96
# Epoch 12
# No Dropout : Train Loss 0.04, Test Acc 0.98
# Dropout    : Train Loss 0.09, Test Acc 0.98
# FBM Dropout: Train Loss 0.05, Test Acc 0.96
# Epoch 13
# No Dropout : Train Loss 0.03, Test Acc 0.98
# Dropout    : Train Loss 0.09, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.96
# Epoch 14
# No Dropout : Train Loss 0.03, Test Acc 0.97
# Dropout    : Train Loss 0.08, Test Acc 0.98
# FBM Dropout: Train Loss 0.05, Test Acc 0.95
# Epoch 15
# No Dropout : Train Loss 0.03, Test Acc 0.98
# Dropout    : Train Loss 0.08, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.95
# Epoch 16
# No Dropout : Train Loss 0.03, Test Acc 0.97
# Dropout    : Train Loss 0.07, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.93
# Epoch 17
# No Dropout : Train Loss 0.03, Test Acc 0.97
# Dropout    : Train Loss 0.07, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.91
# Epoch 18
# No Dropout : Train Loss 0.02, Test Acc 0.97
# Dropout    : Train Loss 0.07, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.94
# Epoch 19
# No Dropout : Train Loss 0.03, Test Acc 0.98
# Dropout    : Train Loss 0.07, Test Acc 0.97
# FBM Dropout: Train Loss 0.04, Test Acc 0.96
# Epoch 20
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.07, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.97
# Epoch 21
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.07, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.96
# Epoch 22
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.07, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.96
# Epoch 23
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.07, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.96
# Epoch 24
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.06, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.95
# Epoch 25
# No Dropout : Train Loss 0.02, Test Acc 0.97
# Dropout    : Train Loss 0.06, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.95
# Epoch 26
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.06, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.96
# Epoch 27
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.06, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.96
# Epoch 28
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.06, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.96
# Epoch 29
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.06, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 30
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.06, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 31
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.06, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 32
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 33
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 34
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 35
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 36
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 37
# No Dropout : Train Loss 0.02, Test Acc 0.97
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.98
# Epoch 38
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.98
# Epoch 39
# No Dropout : Train Loss 0.02, Test Acc 0.97
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.97
# Epoch 40
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.96
# Epoch 41
# No Dropout : Train Loss 0.01, Test Acc 0.97
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 42
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.97
# Epoch 43
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 44
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 45
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 46
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.97
# Epoch 47
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.05, Test Acc 0.97
# Epoch 48
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 49
# No Dropout : Train Loss 0.01, Test Acc 0.97
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 50
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 51
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.05, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.96
# Epoch 52
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.97
# Epoch 53
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 54
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 55
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 56
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 57
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 58
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.96
# Epoch 59
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 60
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 61
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 62
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.94
# Epoch 63
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.95
# Epoch 64
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.95
# Epoch 65
# No Dropout : Train Loss 0.02, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.95
# Epoch 66
# No Dropout : Train Loss 0.01, Test Acc 0.97
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.95
# Epoch 67
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.95
# Epoch 68
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.96
# Epoch 69
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 70
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.05, Test Acc 0.97
# Epoch 71
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 72
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 73
# No Dropout : Train Loss 0.01, Test Acc 0.97
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 74
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 75
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 76
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 77
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 78
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 79
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 80
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 81
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 82
# No Dropout : Train Loss 0.01, Test Acc 0.97
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 83
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 84
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 85
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 86
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 87
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 88
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 89
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 90
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 91
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 92
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 93
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 94
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.97
# Epoch 95
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 96
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 97
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.98
# Epoch 98
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 99
# No Dropout : Train Loss 0.01, Test Acc 0.97
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 100
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 101
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 102
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 103
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 104
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.98
# Epoch 105
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.04, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 106
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 107
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 108
# No Dropout : Train Loss 0.01, Test Acc 0.97
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 109
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 110
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 111
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.96
# Epoch 112
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 113
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 114
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.04, Test Acc 0.97
# Epoch 115
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 116
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 117
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 118
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.98
# Epoch 119
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 120
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 121
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 122
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 123
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 124
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 125
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.95
# Epoch 126
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.96
# Epoch 127
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 128
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 129
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 130
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 131
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 132
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 133
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 134
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 135
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 136
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 137
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 138
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 139
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 140
# No Dropout : Train Loss 0.00, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.96
# Epoch 141
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.95
# Epoch 142
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 143
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 144
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 145
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 146
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 147
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 148
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.96
# Epoch 149
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 150
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 151
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 152
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 153
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.98
# Epoch 154
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.98
# Epoch 155
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 156
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 157
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 158
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 159
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 160
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 161
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 162
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.98
# Epoch 163
# No Dropout : Train Loss 0.00, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 164
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.98
# Epoch 165
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 166
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 167
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.98
# Epoch 168
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 169
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.98
# Epoch 170
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 171
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 172
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.02, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 173
# No Dropout : Train Loss 0.00, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 174
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 175
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 176
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.02, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 177
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 178
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 179
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 180
# No Dropout : Train Loss 0.00, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 181
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 182
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 183
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.02, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 184
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 185
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 186
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 187
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 188
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.02, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 189
# No Dropout : Train Loss 0.00, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 190
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.98
# Epoch 191
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.97
# Epoch 192
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.02, Test Acc 0.98
# FBM Dropout: Train Loss 0.01, Test Acc 0.98
# Epoch 193
# No Dropout : Train Loss 0.00, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.97
# Epoch 194
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 195
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.02, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 196
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.03, Test Acc 0.96
# Epoch 197
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 198
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97
# Epoch 199
# No Dropout : Train Loss 0.01, Test Acc 0.98
# Dropout    : Train Loss 0.03, Test Acc 0.98
# FBM Dropout: Train Loss 0.02, Test Acc 0.97

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
plt.plot(results['train loss']['no dropout'], label='No Dropout')
plt.plot(results['train loss']['dropout'], label='Dropout')
plt.plot(results['train loss']['fbm dropout'], label='FBM Dropout')
plt.title('Train Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(results['test acc']['no dropout'], label='No Dropout')
plt.plot(results['test acc']['dropout'], label='Dropout')
plt.plot(results['test acc']['fbm dropout'], label='FBM Dropout')
plt.title('Test Accuracy')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(results['test acc']['no dropout'], label='No Dropout')
plt.plot(results['test acc']['dropout'], label='Dropout')
plt.plot(results['test acc']['fbm dropout'], label='FBM Dropout')
plt.title('Test Accuracy')
plt.legend()
plt.show()
