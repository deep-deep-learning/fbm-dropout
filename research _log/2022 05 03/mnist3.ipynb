# %%
import torch.nn as nn
import torch.nn.functional as F
from fbm_dropout.fbm_dropout import DropoutFBM

class DenseNetFBM(nn.Module):

    def __init__(self, hidden_sizes, n_agents, max_epoch, grid_sizes, device=None, dtype=None):

        super().__init__()
        
        self.linear_1 = nn.Linear(28*28, hidden_sizes[0], device=device, dtype=dtype)
        self.linear_2 = nn.Linear(hidden_sizes[0], hidden_sizes[1], device=device, dtype=dtype)
        self.linear_3 = nn.Linear(hidden_sizes[1], 10, device=device, dtype=dtype)
        self.dropout_1 = DropoutFBM(0.8, n_agents[0], max_epoch, grid_sizes[0], show=False, device=device, dtype=dtype)
        self.dropout_2 = DropoutFBM(0.8, n_agents[1], max_epoch, grid_sizes[1], show=False, device=device, dtype=dtype)

    def forward(self, input, current_epoch):

        if self.training:
            output = F.relu(self.dropout_1(self.linear_1(input), current_epoch))
            output = F.relu(self.dropout_2(self.linear_2(output), current_epoch))
        else:
            output = F.relu(self.linear_1(input))
            output = F.relu(self.linear_2(output))
            
        output = self.linear_3(output)
        
        return output

# %%
import torch.nn as nn
import torch.nn.functional as F

class DenseNet(nn.Module):

    def __init__(self, hidden_sizes, dropout_rate, device=None, dtype=None):

        super().__init__()
        
        self.linear_1 = nn.Linear(784, hidden_sizes[0], device=device, dtype=dtype)
        self.linear_2 = nn.Linear(hidden_sizes[0], hidden_sizes[1], device=device, dtype=dtype)
        self.linear_3 = nn.Linear(hidden_sizes[1], 10, device=device, dtype=dtype)
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, input):

        output = F.relu(self.dropout(self.linear_1(input)))
        output = F.relu(self.dropout(self.linear_2(output)))
        output = self.linear_3(output)
        return output

# %%
from torchvision import datasets, transforms
import torch

transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),])

trainset = datasets.MNIST('~/datasets', download=True, train=True, transform=transform)
train_loader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = datasets.MNIST('~/datasets', download=True, train=False, transform=transform)
test_loader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# %%
import torch.optim as optim

hidden_sizes = [1024, 256]
max_epochs = 1000
grid_sizes = [(32,32), (16,16)]
n_agents = [64, 16]
device='cuda'

model = DenseNet(hidden_sizes, 0, device=device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

model_dropout = DenseNet(hidden_sizes, .2, device=device)
optimizer_dropout = optim.Adam(model_dropout.parameters(), lr=0.001)

model_fbm_dropout = DenseNetFBM(hidden_sizes, n_agents, max_epochs, grid_sizes, device=device)
optimizer_fbm_dropout = optim.Adam(model_fbm_dropout.parameters(), lr=0.001)

criterion = nn.CrossEntropyLoss()

# %%
results = {}
results['train loss'] = {}
results['train loss']['no dropout'] = []
results['train loss']['dropout'] = []
results['train loss']['fbm dropout'] = []
results['test acc'] = {}
results['test acc']['no dropout'] = []
results['test acc']['dropout'] = []
results['test acc']['fbm dropout'] = []
for epoch in range(max_epochs):
    model.train()
    model_dropout.train()
    model_fbm_dropout.train()

    running_loss = {}
    running_loss['no dropout'] = running_loss['dropout'] = running_loss['fbm dropout'] = 0.0
    for images, labels in train_loader:

        images = images.view(images.shape[0], -1).to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        optimizer_dropout.zero_grad()
        optimizer_fbm_dropout.zero_grad()

        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        running_loss['no dropout'] += loss.item()

        output_dropout = model_dropout(images)
        loss_dropout = criterion(output_dropout, labels)
        loss_dropout.backward()
        optimizer_dropout.step()
        running_loss['dropout'] += loss_dropout.item()

        output_fbm_dropout = model_fbm_dropout(images, epoch)
        loss_fbm_dropout = criterion(output_fbm_dropout, labels)
        loss_fbm_dropout.backward()
        optimizer_fbm_dropout.step()
        running_loss['fbm dropout'] += loss_fbm_dropout.item()

    results['train loss']['no dropout'].append(running_loss['no dropout'] / len(train_loader))
    results['train loss']['dropout'].append(running_loss['dropout'] / len(train_loader))
    results['train loss']['fbm dropout'].append(running_loss['fbm dropout'] / len(train_loader))

    model.eval()
    model_dropout.eval()
    model_fbm_dropout.eval()
    acc = acc_dropout = acc_fbm_dropout = 0.0
    for images, labels in test_loader:
        images = images.view(-1,784).to(device)
        labels = labels.to(device)
        output = model(images)
        _, pred = torch.max(output, axis=1)
        acc += torch.sum(pred==labels).item()

        output_dropout = model_dropout(images)
        _, pred_dropout = torch.max(output_dropout, axis=1)
        acc_dropout += torch.sum(pred_dropout==labels).item()

        output_fbm_dropout = model_fbm_dropout(images, epoch)
        _, pred_fbm_dropout = torch.max(output_fbm_dropout, axis=1)
        acc_fbm_dropout += torch.sum(pred_fbm_dropout==labels).item()
    
    results['test acc']['no dropout'].append(acc / len(testset))
    results['test acc']['dropout'].append(acc_dropout / len(testset))
    results['test acc']['fbm dropout'].append(acc_fbm_dropout / len(testset))

    if epoch % 10 == 0:
        print('Epoch {}'.format(epoch))
        print('No Dropout : Train Loss {:.4f}, Test Acc {:.4f}'.format(results['train loss']['no dropout'][-1], 
                                                                    results['test acc']['no dropout'][-1]))
        print('Dropout    : Train Loss {:.4f}, Test Acc {:.4f}'.format(results['train loss']['dropout'][-1], 
                                                                    results['test acc']['dropout'][-1]))
        print('FBM Dropout: Train Loss {:.4f}, Test Acc {:.4f}, Drop Rate {:.4f} {:.4f}'.format(results['train loss']['fbm dropout'][-1], 
                                                                                        results['test acc']['fbm dropout'][-1], 
                                                                                        model_fbm_dropout.dropout_1.curr_dropout_rate, 
                                                                                        model_fbm_dropout.dropout_2.curr_dropout_rate))
# Out:
# Epoch 0
# No Dropout : Train Loss 0.2815, Test Acc 0.9457
# Dropout    : Train Loss 0.3248, Test Acc 0.9452
# FBM Dropout: Train Loss 0.2884, Test Acc 0.9505, Drop Rate 0.1406 0.1523
# Epoch 10
# No Dropout : Train Loss 0.0330, Test Acc 0.9742
# Dropout    : Train Loss 0.0707, Test Acc 0.9776
# FBM Dropout: Train Loss 0.0464, Test Acc 0.9719, Drop Rate 0.1414 0.1438
# Epoch 20
# No Dropout : Train Loss 0.0252, Test Acc 0.9807
# Dropout    : Train Loss 0.0550, Test Acc 0.9817
# FBM Dropout: Train Loss 0.0347, Test Acc 0.9799, Drop Rate 0.1424 0.1423
# Epoch 30
# No Dropout : Train Loss 0.0147, Test Acc 0.9787
# Dropout    : Train Loss 0.0483, Test Acc 0.9814
# FBM Dropout: Train Loss 0.0276, Test Acc 0.9813, Drop Rate 0.1434 0.1443
# Epoch 40
# No Dropout : Train Loss 0.0159, Test Acc 0.9803
# Dropout    : Train Loss 0.0410, Test Acc 0.9809
# FBM Dropout: Train Loss 0.0250, Test Acc 0.9766, Drop Rate 0.1455 0.1421
# Epoch 50
# No Dropout : Train Loss 0.0165, Test Acc 0.9791
# Dropout    : Train Loss 0.0385, Test Acc 0.9838
# FBM Dropout: Train Loss 0.0146, Test Acc 0.9798, Drop Rate 0.1454 0.1419
# Epoch 60
# No Dropout : Train Loss 0.0094, Test Acc 0.9834
# Dropout    : Train Loss 0.0371, Test Acc 0.9825
# FBM Dropout: Train Loss 0.0244, Test Acc 0.9771, Drop Rate 0.1448 0.1420
# Epoch 70
# No Dropout : Train Loss 0.0072, Test Acc 0.9826
# Dropout    : Train Loss 0.0390, Test Acc 0.9822
# FBM Dropout: Train Loss 0.0178, Test Acc 0.9759, Drop Rate 0.1448 0.1420
# Epoch 80
# No Dropout : Train Loss 0.0138, Test Acc 0.9822
# Dropout    : Train Loss 0.0368, Test Acc 0.9831
# FBM Dropout: Train Loss 0.0203, Test Acc 0.9821, Drop Rate 0.1442 0.1432
# Epoch 90
# No Dropout : Train Loss 0.0171, Test Acc 0.9796
# Dropout    : Train Loss 0.0391, Test Acc 0.9828
# FBM Dropout: Train Loss 0.0168, Test Acc 0.9822, Drop Rate 0.1445 0.1432
# Epoch 100
# No Dropout : Train Loss 0.0114, Test Acc 0.9810
# Dropout    : Train Loss 0.0295, Test Acc 0.9822
# FBM Dropout: Train Loss 0.0219, Test Acc 0.9831, Drop Rate 0.1446 0.1432
# Epoch 110
# No Dropout : Train Loss 0.0133, Test Acc 0.9807
# Dropout    : Train Loss 0.0309, Test Acc 0.9801
# FBM Dropout: Train Loss 0.0264, Test Acc 0.9818, Drop Rate 0.1447 0.1440
# Epoch 120
# No Dropout : Train Loss 0.0069, Test Acc 0.9816
# Dropout    : Train Loss 0.0349, Test Acc 0.9835
# FBM Dropout: Train Loss 0.0159, Test Acc 0.9773, Drop Rate 0.1446 0.1445
# Epoch 130
# No Dropout : Train Loss 0.0110, Test Acc 0.9783
# Dropout    : Train Loss 0.0289, Test Acc 0.9838
# FBM Dropout: Train Loss 0.0193, Test Acc 0.9808, Drop Rate 0.1444 0.1444
# Epoch 140
# No Dropout : Train Loss 0.0116, Test Acc 0.9823
# Dropout    : Train Loss 0.0270, Test Acc 0.9834
# FBM Dropout: Train Loss 0.0243, Test Acc 0.9800, Drop Rate 0.1443 0.1439
# Epoch 150
# No Dropout : Train Loss 0.0159, Test Acc 0.9821
# Dropout    : Train Loss 0.0309, Test Acc 0.9854
# FBM Dropout: Train Loss 0.0140, Test Acc 0.9813, Drop Rate 0.1443 0.1443
# Epoch 160
# No Dropout : Train Loss 0.0112, Test Acc 0.9812
# Dropout    : Train Loss 0.0345, Test Acc 0.9853
# FBM Dropout: Train Loss 0.0183, Test Acc 0.9823, Drop Rate 0.1443 0.1444
# Epoch 170
# No Dropout : Train Loss 0.0066, Test Acc 0.9805
# Dropout    : Train Loss 0.0293, Test Acc 0.9836
# FBM Dropout: Train Loss 0.0183, Test Acc 0.9825, Drop Rate 0.1442 0.1441
# Epoch 180
# No Dropout : Train Loss 0.0099, Test Acc 0.9802
# Dropout    : Train Loss 0.0316, Test Acc 0.9815
# FBM Dropout: Train Loss 0.0198, Test Acc 0.9826, Drop Rate 0.1444 0.1441
# Epoch 190
# No Dropout : Train Loss 0.0153, Test Acc 0.9819
# Dropout    : Train Loss 0.0323, Test Acc 0.9844
# FBM Dropout: Train Loss 0.0226, Test Acc 0.9777, Drop Rate 0.1443 0.1443
# Epoch 200
# No Dropout : Train Loss 0.0113, Test Acc 0.9821
# Dropout    : Train Loss 0.0374, Test Acc 0.9844
# FBM Dropout: Train Loss 0.0187, Test Acc 0.9825, Drop Rate 0.1442 0.1449
# Epoch 210
# No Dropout : Train Loss 0.0112, Test Acc 0.9816
# Dropout    : Train Loss 0.0309, Test Acc 0.9837
# FBM Dropout: Train Loss 0.0129, Test Acc 0.9826, Drop Rate 0.1439 0.1447
# Epoch 220
# No Dropout : Train Loss 0.0091, Test Acc 0.9817
# Dropout    : Train Loss 0.0336, Test Acc 0.9843
# FBM Dropout: Train Loss 0.0140, Test Acc 0.9807, Drop Rate 0.1437 0.1451
# Epoch 230
# No Dropout : Train Loss 0.0071, Test Acc 0.9821
# Dropout    : Train Loss 0.0320, Test Acc 0.9836
# FBM Dropout: Train Loss 0.0179, Test Acc 0.9807, Drop Rate 0.1438 0.1448
# Epoch 240
# No Dropout : Train Loss 0.0145, Test Acc 0.9814
# Dropout    : Train Loss 0.0350, Test Acc 0.9839
# FBM Dropout: Train Loss 0.0228, Test Acc 0.9804, Drop Rate 0.1437 0.1449
# Epoch 250
# No Dropout : Train Loss 0.0154, Test Acc 0.9838
# Dropout    : Train Loss 0.0262, Test Acc 0.9849
# FBM Dropout: Train Loss 0.0188, Test Acc 0.9806, Drop Rate 0.1439 0.1449
# Epoch 260
# No Dropout : Train Loss 0.0107, Test Acc 0.9780
# Dropout    : Train Loss 0.0304, Test Acc 0.9838
# FBM Dropout: Train Loss 0.0171, Test Acc 0.9826, Drop Rate 0.1438 0.1447
# Epoch 270
# No Dropout : Train Loss 0.0137, Test Acc 0.9824
# Dropout    : Train Loss 0.0245, Test Acc 0.9852
# FBM Dropout: Train Loss 0.0208, Test Acc 0.9787, Drop Rate 0.1439 0.1450
# Epoch 280
# No Dropout : Train Loss 0.0066, Test Acc 0.9816
# Dropout    : Train Loss 0.0300, Test Acc 0.9847
# FBM Dropout: Train Loss 0.0185, Test Acc 0.9805, Drop Rate 0.1440 0.1451
# Epoch 290
# No Dropout : Train Loss 0.0111, Test Acc 0.9804
# Dropout    : Train Loss 0.0287, Test Acc 0.9845
# FBM Dropout: Train Loss 0.0256, Test Acc 0.9822, Drop Rate 0.1440 0.1446
# Epoch 300
# No Dropout : Train Loss 0.0129, Test Acc 0.9781
# Dropout    : Train Loss 0.0333, Test Acc 0.9830
# FBM Dropout: Train Loss 0.0213, Test Acc 0.9797, Drop Rate 0.1441 0.1445
# Epoch 310
# No Dropout : Train Loss 0.0248, Test Acc 0.9814
# Dropout    : Train Loss 0.0338, Test Acc 0.9835
# FBM Dropout: Train Loss 0.0186, Test Acc 0.9810, Drop Rate 0.1442 0.1452
# Epoch 320
# No Dropout : Train Loss 0.0202, Test Acc 0.9800
# Dropout    : Train Loss 0.0307, Test Acc 0.9859
# FBM Dropout: Train Loss 0.0235, Test Acc 0.9809, Drop Rate 0.1442 0.1449
# Epoch 330
# No Dropout : Train Loss 0.0076, Test Acc 0.9831
# Dropout    : Train Loss 0.0334, Test Acc 0.9858
# FBM Dropout: Train Loss 0.0200, Test Acc 0.9821, Drop Rate 0.1443 0.1447
# Epoch 340
# No Dropout : Train Loss 0.0147, Test Acc 0.9825
# Dropout    : Train Loss 0.0339, Test Acc 0.9843
# FBM Dropout: Train Loss 0.0207, Test Acc 0.9825, Drop Rate 0.1444 0.1446
# Epoch 350
# No Dropout : Train Loss 0.0106, Test Acc 0.9842
# Dropout    : Train Loss 0.0376, Test Acc 0.9838
# FBM Dropout: Train Loss 0.0220, Test Acc 0.9817, Drop Rate 0.1445 0.1446
# Epoch 360
# No Dropout : Train Loss 0.0118, Test Acc 0.9810
# Dropout    : Train Loss 0.0348, Test Acc 0.9830
# FBM Dropout: Train Loss 0.0139, Test Acc 0.9797, Drop Rate 0.1445 0.1447
# Epoch 370
# No Dropout : Train Loss 0.0144, Test Acc 0.9839
# Dropout    : Train Loss 0.0329, Test Acc 0.9828
# FBM Dropout: Train Loss 0.0153, Test Acc 0.9829, Drop Rate 0.1445 0.1445
# Epoch 380
# No Dropout : Train Loss 0.0148, Test Acc 0.9808
# Dropout    : Train Loss 0.0313, Test Acc 0.9805
# FBM Dropout: Train Loss 0.0211, Test Acc 0.9822, Drop Rate 0.1446 0.1448
# Epoch 390
# No Dropout : Train Loss 0.0096, Test Acc 0.9833
# Dropout    : Train Loss 0.0375, Test Acc 0.9829
# FBM Dropout: Train Loss 0.0149, Test Acc 0.9817, Drop Rate 0.1446 0.1446
# Epoch 400
# No Dropout : Train Loss 0.0147, Test Acc 0.9841
# Dropout    : Train Loss 0.0334, Test Acc 0.9845
# FBM Dropout: Train Loss 0.0188, Test Acc 0.9844, Drop Rate 0.1445 0.1446
# Epoch 410
# No Dropout : Train Loss 0.0174, Test Acc 0.9795
# Dropout    : Train Loss 0.0366, Test Acc 0.9832
# FBM Dropout: Train Loss 0.0128, Test Acc 0.9829, Drop Rate 0.1446 0.1448
# Epoch 420
# No Dropout : Train Loss 0.0137, Test Acc 0.9828
# Dropout    : Train Loss 0.0375, Test Acc 0.9844
# FBM Dropout: Train Loss 0.0238, Test Acc 0.9811, Drop Rate 0.1446 0.1447
# Epoch 430
# No Dropout : Train Loss 0.0104, Test Acc 0.9810
# Dropout    : Train Loss 0.0302, Test Acc 0.9832
# FBM Dropout: Train Loss 0.0207, Test Acc 0.9821, Drop Rate 0.1446 0.1446
# Epoch 440
# No Dropout : Train Loss 0.0196, Test Acc 0.9820
# Dropout    : Train Loss 0.0397, Test Acc 0.9813
# FBM Dropout: Train Loss 0.0224, Test Acc 0.9817, Drop Rate 0.1446 0.1449
# Epoch 450
# No Dropout : Train Loss 0.0154, Test Acc 0.9825
# Dropout    : Train Loss 0.0304, Test Acc 0.9829
# FBM Dropout: Train Loss 0.0169, Test Acc 0.9826, Drop Rate 0.1445 0.1447
# Epoch 460
# No Dropout : Train Loss 0.0083, Test Acc 0.9849
# Dropout    : Train Loss 0.0351, Test Acc 0.9835
# FBM Dropout: Train Loss 0.0060, Test Acc 0.9849, Drop Rate 0.1444 0.1449
# Epoch 470
# No Dropout : Train Loss 0.0126, Test Acc 0.9809
# Dropout    : Train Loss 0.0348, Test Acc 0.9848
# FBM Dropout: Train Loss 0.0219, Test Acc 0.9800, Drop Rate 0.1445 0.1449
# Epoch 480
# No Dropout : Train Loss 0.0080, Test Acc 0.9833
# Dropout    : Train Loss 0.0308, Test Acc 0.9848
# FBM Dropout: Train Loss 0.0291, Test Acc 0.9807, Drop Rate 0.1444 0.1450
# Epoch 490
# No Dropout : Train Loss 0.0175, Test Acc 0.9826
# Dropout    : Train Loss 0.0391, Test Acc 0.9825
# FBM Dropout: Train Loss 0.0151, Test Acc 0.9820, Drop Rate 0.1444 0.1450
# Epoch 500
# No Dropout : Train Loss 0.0072, Test Acc 0.9846
# Dropout    : Train Loss 0.0403, Test Acc 0.9845
# FBM Dropout: Train Loss 0.0184, Test Acc 0.9816, Drop Rate 0.1445 0.1449
# Epoch 510
# No Dropout : Train Loss 0.0066, Test Acc 0.9819
# Dropout    : Train Loss 0.0326, Test Acc 0.9824
# FBM Dropout: Train Loss 0.0148, Test Acc 0.9818, Drop Rate 0.1445 0.1450
# Epoch 520
# No Dropout : Train Loss 0.0145, Test Acc 0.9824
# Dropout    : Train Loss 0.0284, Test Acc 0.9823
# FBM Dropout: Train Loss 0.0109, Test Acc 0.9811, Drop Rate 0.1445 0.1451
# Epoch 530
# No Dropout : Train Loss 0.0117, Test Acc 0.9824
# Dropout    : Train Loss 0.0378, Test Acc 0.9831
# FBM Dropout: Train Loss 0.0189, Test Acc 0.9823, Drop Rate 0.1444 0.1451
# Epoch 540
# No Dropout : Train Loss 0.0103, Test Acc 0.9830
# Dropout    : Train Loss 0.0327, Test Acc 0.9853
# FBM Dropout: Train Loss 0.0108, Test Acc 0.9828, Drop Rate 0.1445 0.1450
# Epoch 550
# No Dropout : Train Loss 0.0185, Test Acc 0.9820
# Dropout    : Train Loss 0.0328, Test Acc 0.9826
# FBM Dropout: Train Loss 0.0210, Test Acc 0.9826, Drop Rate 0.1445 0.1447
# Epoch 560
# No Dropout : Train Loss 0.0127, Test Acc 0.9831
# Dropout    : Train Loss 0.0332, Test Acc 0.9846
# FBM Dropout: Train Loss 0.0200, Test Acc 0.9827, Drop Rate 0.1446 0.1447
# Epoch 570
# No Dropout : Train Loss 0.0191, Test Acc 0.9801
# Dropout    : Train Loss 0.0363, Test Acc 0.9821
# FBM Dropout: Train Loss 0.0240, Test Acc 0.9827, Drop Rate 0.1446 0.1447
# Epoch 580
# No Dropout : Train Loss 0.0000, Test Acc 0.9843
# Dropout    : Train Loss 0.0403, Test Acc 0.9849
# FBM Dropout: Train Loss 0.0190, Test Acc 0.9796, Drop Rate 0.1446 0.1445
# Epoch 590
# No Dropout : Train Loss 0.0000, Test Acc 0.9843
# Dropout    : Train Loss 0.0316, Test Acc 0.9841
# FBM Dropout: Train Loss 0.0278, Test Acc 0.9798, Drop Rate 0.1445 0.1447
# Epoch 600
# No Dropout : Train Loss 0.0000, Test Acc 0.9841
# Dropout    : Train Loss 0.0402, Test Acc 0.9838
# FBM Dropout: Train Loss 0.0243, Test Acc 0.9840, Drop Rate 0.1445 0.1447
# Epoch 610
# No Dropout : Train Loss 0.0000, Test Acc 0.9841
# Dropout    : Train Loss 0.0340, Test Acc 0.9845
# FBM Dropout: Train Loss 0.0153, Test Acc 0.9844, Drop Rate 0.1446 0.1448
# Epoch 620
# No Dropout : Train Loss 0.0000, Test Acc 0.9841
# Dropout    : Train Loss 0.0380, Test Acc 0.9836
# FBM Dropout: Train Loss 0.0131, Test Acc 0.9844, Drop Rate 0.1446 0.1447
# Epoch 630
# No Dropout : Train Loss 0.0000, Test Acc 0.9841
# Dropout    : Train Loss 0.0402, Test Acc 0.9844
# FBM Dropout: Train Loss 0.0246, Test Acc 0.9797, Drop Rate 0.1445 0.1447
# Epoch 640
# No Dropout : Train Loss 0.0000, Test Acc 0.9841
# Dropout    : Train Loss 0.0338, Test Acc 0.9857
# FBM Dropout: Train Loss 0.0134, Test Acc 0.9828, Drop Rate 0.1446 0.1447
# Epoch 650
# No Dropout : Train Loss 0.0000, Test Acc 0.9841
# Dropout    : Train Loss 0.0357, Test Acc 0.9845
# FBM Dropout: Train Loss 0.0134, Test Acc 0.9833, Drop Rate 0.1445 0.1447
# Epoch 660
# No Dropout : Train Loss 0.0000, Test Acc 0.9841
# Dropout    : Train Loss 0.0306, Test Acc 0.9854
# FBM Dropout: Train Loss 0.0205, Test Acc 0.9825, Drop Rate 0.1446 0.1447
# Epoch 670
# No Dropout : Train Loss 0.0000, Test Acc 0.9840
# Dropout    : Train Loss 0.0328, Test Acc 0.9840
# FBM Dropout: Train Loss 0.0417, Test Acc 0.9822, Drop Rate 0.1446 0.1447
# Epoch 680
# No Dropout : Train Loss 0.0000, Test Acc 0.9841
# Dropout    : Train Loss 0.0367, Test Acc 0.9834
# FBM Dropout: Train Loss 0.0189, Test Acc 0.9802, Drop Rate 0.1445 0.1447
# Epoch 690
# No Dropout : Train Loss 0.0000, Test Acc 0.9840
# Dropout    : Train Loss 0.0437, Test Acc 0.9839
# FBM Dropout: Train Loss 0.0169, Test Acc 0.9828, Drop Rate 0.1445 0.1446
# Epoch 700
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0374, Test Acc 0.9826
# FBM Dropout: Train Loss 0.0235, Test Acc 0.9831, Drop Rate 0.1445 0.1445
# Epoch 710
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0327, Test Acc 0.9839
# FBM Dropout: Train Loss 0.0328, Test Acc 0.9799, Drop Rate 0.1446 0.1444
# Epoch 720
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0353, Test Acc 0.9861
# FBM Dropout: Train Loss 0.0190, Test Acc 0.9818, Drop Rate 0.1445 0.1444
# Epoch 730
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0438, Test Acc 0.9824
# FBM Dropout: Train Loss 0.0191, Test Acc 0.9829, Drop Rate 0.1445 0.1444
# Epoch 740
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0469, Test Acc 0.9788
# FBM Dropout: Train Loss 0.0229, Test Acc 0.9836, Drop Rate 0.1445 0.1443
# Epoch 750
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0350, Test Acc 0.9850
# FBM Dropout: Train Loss 0.0149, Test Acc 0.9818, Drop Rate 0.1444 0.1443
# Epoch 760
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0374, Test Acc 0.9851
# FBM Dropout: Train Loss 0.0220, Test Acc 0.9815, Drop Rate 0.1444 0.1443
# Epoch 770
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0419, Test Acc 0.9854
# FBM Dropout: Train Loss 0.0224, Test Acc 0.9790, Drop Rate 0.1445 0.1444
# Epoch 780
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0350, Test Acc 0.9816
# FBM Dropout: Train Loss 0.0250, Test Acc 0.9796, Drop Rate 0.1444 0.1443
# Epoch 790
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0402, Test Acc 0.9833
# FBM Dropout: Train Loss 0.0147, Test Acc 0.9816, Drop Rate 0.1444 0.1442
# Epoch 800
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0458, Test Acc 0.9830
# FBM Dropout: Train Loss 0.0116, Test Acc 0.9815, Drop Rate 0.1445 0.1442
# Epoch 810
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0489, Test Acc 0.9828
# FBM Dropout: Train Loss 0.1221, Test Acc 0.9720, Drop Rate 0.1445 0.1442
# Epoch 820
# No Dropout : Train Loss 0.0000, Test Acc 0.9838
# Dropout    : Train Loss 0.0447, Test Acc 0.9840
# FBM Dropout: Train Loss 0.0109, Test Acc 0.9820, Drop Rate 0.1445 0.1442
# Epoch 830
# No Dropout : Train Loss 0.0000, Test Acc 0.9837
# Dropout    : Train Loss 0.0350, Test Acc 0.9838
# FBM Dropout: Train Loss 0.0214, Test Acc 0.9828, Drop Rate 0.1446 0.1442
# Epoch 840
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0379, Test Acc 0.9815
# FBM Dropout: Train Loss 0.0179, Test Acc 0.9836, Drop Rate 0.1445 0.1442
# Epoch 850
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0360, Test Acc 0.9844
# FBM Dropout: Train Loss 0.0212, Test Acc 0.9757, Drop Rate 0.1446 0.1442
# Epoch 860
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0319, Test Acc 0.9858
# FBM Dropout: Train Loss 0.0238, Test Acc 0.9844, Drop Rate 0.1446 0.1441
# Epoch 870
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0403, Test Acc 0.9823
# FBM Dropout: Train Loss 0.0236, Test Acc 0.9732, Drop Rate 0.1446 0.1441
# Epoch 880
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0451, Test Acc 0.9841
# FBM Dropout: Train Loss 0.0171, Test Acc 0.9847, Drop Rate 0.1446 0.1442
# Epoch 890
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0378, Test Acc 0.9839
# FBM Dropout: Train Loss 0.0107, Test Acc 0.9823, Drop Rate 0.1446 0.1441
# Epoch 900
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0490, Test Acc 0.9841
# FBM Dropout: Train Loss 0.0162, Test Acc 0.9837, Drop Rate 0.1447 0.1440
# Epoch 910
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0258, Test Acc 0.9851
# FBM Dropout: Train Loss 0.0181, Test Acc 0.9842, Drop Rate 0.1447 0.1440
# Epoch 920
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0642, Test Acc 0.9837
# FBM Dropout: Train Loss 0.0366, Test Acc 0.9821, Drop Rate 0.1447 0.1440
# Epoch 930
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0666, Test Acc 0.9821
# FBM Dropout: Train Loss 0.0341, Test Acc 0.9812, Drop Rate 0.1447 0.1439
# Epoch 940
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0471, Test Acc 0.9825
# FBM Dropout: Train Loss 0.0192, Test Acc 0.9803, Drop Rate 0.1447 0.1439
# Epoch 950
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0326, Test Acc 0.9842
# FBM Dropout: Train Loss 0.0275, Test Acc 0.9823, Drop Rate 0.1447 0.1440
# Epoch 960
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0476, Test Acc 0.9840
# FBM Dropout: Train Loss 0.0186, Test Acc 0.9849, Drop Rate 0.1447 0.1440
# Epoch 970
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0440, Test Acc 0.9867
# FBM Dropout: Train Loss 0.0151, Test Acc 0.9814, Drop Rate 0.1447 0.1440
# Epoch 980
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0416, Test Acc 0.9838
# FBM Dropout: Train Loss 0.0165, Test Acc 0.9839, Drop Rate 0.1446 0.1439
# Epoch 990
# No Dropout : Train Loss 0.0000, Test Acc 0.9836
# Dropout    : Train Loss 0.0489, Test Acc 0.9831
# FBM Dropout: Train Loss 0.0180, Test Acc 0.9809, Drop Rate 0.1447 0.1440

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(results['train loss']['no dropout'], label='No Dropout')
plt.plot(results['train loss']['dropout'], label='Dropout')
plt.plot(results['train loss']['fbm dropout'], label='FBM Dropout')
plt.title('Train Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(results['test acc']['no dropout'], label='No Dropout')
plt.plot(results['test acc']['dropout'], label='Dropout')
plt.plot(results['test acc']['fbm dropout'], label='FBM Dropout')
plt.title('Test Accuracy')
plt.legend()
plt.show()

# %%
print(model_fbm_dropout.dropout_1.curr_dropout_rate)
print(model_fbm_dropout.dropout_2.curr_dropout_rate)
# Out:
# 0.1446611328125
# 0.143921875
