# %%
from fbm_dropout.net import DenseNet, DenseNetFBM_with_branching
import torch.optim as optim
import torch.nn as nn

hidden_sizes = [256, 64]
grid_sizes = [(16,16), (8,8)]
n_agents = [26, 12]
device='cuda'

model = DenseNet(hidden_sizes, 0, device=device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

model_dropout = DenseNet(hidden_sizes, .20, device=device)
optimizer_dropout = optim.Adam(model_dropout.parameters(), lr=0.001)

model_fbm_dropout = DenseNetFBM_with_branching(hidden_sizes, n_agents, 100, 1000, 10, grid_sizes, show=False, device=device)
optimizer_fbm_dropout = optim.Adam(model_fbm_dropout.parameters(), lr=0.001)

criterion = nn.CrossEntropyLoss()

# %%
import torch
from fbm_dropout.dataset import get_MNIST_dataset

trainset, testset = get_MNIST_dataset()
batch_size = 64
train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=True)

# %%
results = {}
results['train loss'] = {}
results['train loss']['no dropout'] = []
results['train loss']['dropout'] = []
results['train loss']['fbm dropout'] = []
results['test acc'] = {}
results['test acc']['no dropout'] = []
results['test acc']['dropout'] = []
results['test acc']['fbm dropout'] = []
for epoch in range(50):
    model.train()
    model_dropout.train()
    model_fbm_dropout.train()

    running_loss = {}
    running_loss['no dropout'] = running_loss['dropout'] = running_loss['fbm dropout'] = 0.0
    for images, labels in train_loader:

        images = images.view(images.shape[0], -1).to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        optimizer_dropout.zero_grad()
        optimizer_fbm_dropout.zero_grad()

        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        running_loss['no dropout'] += loss.item()

        output_dropout = model_dropout(images)
        loss_dropout = criterion(output_dropout, labels)
        loss_dropout.backward()
        optimizer_dropout.step()
        running_loss['dropout'] += loss_dropout.item()

        output_fbm_dropout = model_fbm_dropout(images)
        loss_fbm_dropout = criterion(output_fbm_dropout, labels)
        loss_fbm_dropout.backward()
        optimizer_fbm_dropout.step()
        running_loss['fbm dropout'] += loss_fbm_dropout.item()

    results['train loss']['no dropout'].append(running_loss['no dropout'] / len(train_loader))
    results['train loss']['dropout'].append(running_loss['dropout'] / len(train_loader))
    results['train loss']['fbm dropout'].append(running_loss['fbm dropout'] / len(train_loader))

    model.eval()
    model_dropout.eval()
    model_fbm_dropout.eval()
    acc = acc_dropout = acc_fbm_dropout = 0.0
    for images, labels in test_loader:
        images = images.view(-1,784).to(device)
        labels = labels.to(device)
        output = model(images)
        _, pred = torch.max(output, axis=1)
        acc += torch.sum(pred==labels).item()

        output_dropout = model_dropout(images)
        _, pred_dropout = torch.max(output_dropout, axis=1)
        acc_dropout += torch.sum(pred_dropout==labels).item()

        output_fbm_dropout = model_fbm_dropout(images)
        _, pred_fbm_dropout = torch.max(output_fbm_dropout, axis=1)
        acc_fbm_dropout += torch.sum(pred_fbm_dropout==labels).item()
    
    results['test acc']['no dropout'].append(acc / len(testset))
    results['test acc']['dropout'].append(acc_dropout / len(testset))
    results['test acc']['fbm dropout'].append(acc_fbm_dropout / len(testset))

    model_fbm_dropout.dropout_1.branch_off()
    model_fbm_dropout.dropout_2.branch_off()

    
    print('Epoch {}'.format(epoch))
    print('No Dropout : Train Loss {:.4f}, Test Acc {:.4f}'.format(results['train loss']['no dropout'][-1], results['test acc']['no dropout'][-1]))
    print('Dropout    : Train Loss {:.4f}, Test Acc {:.4f}'.format(results['train loss']['dropout'][-1], results['test acc']['dropout'][-1]))
    print('FBM Dropout: Train Loss {:.4f}, Test Acc {:.4f}, Drop Rate {:.4f} {:.4f}'.format(results['train loss']['fbm dropout'][-1], 
                                                                                        results['test acc']['fbm dropout'][-1], 
                                                                                        model_fbm_dropout.dropout_1.cum_dropout_rate, 
                                                                                        model_fbm_dropout.dropout_2.cum_dropout_rate))
# Out:
# Epoch 0
# No Dropout : Train Loss 0.3644, Test Acc 0.9395
# Dropout    : Train Loss 0.4342, Test Acc 0.9399
# FBM Dropout: Train Loss 0.4982, Test Acc 0.9381, Drop Rate 0.1963 0.2045
# Epoch 1
# No Dropout : Train Loss 0.1619, Test Acc 0.9588
# Dropout    : Train Loss 0.2178, Test Acc 0.9572
# FBM Dropout: Train Loss 0.2428, Test Acc 0.9519, Drop Rate 0.1962 0.2009
# Epoch 2
# No Dropout : Train Loss 0.1166, Test Acc 0.9645
# Dropout    : Train Loss 0.1746, Test Acc 0.9597
# FBM Dropout: Train Loss 0.1883, Test Acc 0.9598, Drop Rate 0.1970 0.2012
# Epoch 3
# No Dropout : Train Loss 0.0958, Test Acc 0.9716
# Dropout    : Train Loss 0.1503, Test Acc 0.9656
# FBM Dropout: Train Loss 0.1653, Test Acc 0.9656, Drop Rate 0.1989 0.1994
# Epoch 4
# No Dropout : Train Loss 0.0797, Test Acc 0.9685
# Dropout    : Train Loss 0.1344, Test Acc 0.9689
# FBM Dropout: Train Loss 0.1397, Test Acc 0.9696, Drop Rate 0.1988 0.1997
# Epoch 5
# No Dropout : Train Loss 0.0705, Test Acc 0.9717
# Dropout    : Train Loss 0.1258, Test Acc 0.9740
# FBM Dropout: Train Loss 0.1294, Test Acc 0.9686, Drop Rate 0.1988 0.1999
# Epoch 6
# No Dropout : Train Loss 0.0597, Test Acc 0.9749
# Dropout    : Train Loss 0.1183, Test Acc 0.9719
# FBM Dropout: Train Loss 0.1209, Test Acc 0.9654, Drop Rate 0.1982 0.2008
# Epoch 7
# No Dropout : Train Loss 0.0561, Test Acc 0.9754
# Dropout    : Train Loss 0.1108, Test Acc 0.9699
# FBM Dropout: Train Loss 0.1174, Test Acc 0.9744, Drop Rate 0.1980 0.2007
# Epoch 8
# No Dropout : Train Loss 0.0506, Test Acc 0.9790
# Dropout    : Train Loss 0.1066, Test Acc 0.9693
# FBM Dropout: Train Loss 0.1077, Test Acc 0.9746, Drop Rate 0.1981 0.2010
# Epoch 9
# No Dropout : Train Loss 0.0455, Test Acc 0.9744
# Dropout    : Train Loss 0.1030, Test Acc 0.9730
# FBM Dropout: Train Loss 0.1048, Test Acc 0.9724, Drop Rate 0.1985 0.2008
# Epoch 10
# No Dropout : Train Loss 0.0402, Test Acc 0.9746
# Dropout    : Train Loss 0.0967, Test Acc 0.9773
# FBM Dropout: Train Loss 0.1004, Test Acc 0.9748, Drop Rate 0.1988 0.2004
# Epoch 11
# No Dropout : Train Loss 0.0370, Test Acc 0.9704
# Dropout    : Train Loss 0.0941, Test Acc 0.9737
# FBM Dropout: Train Loss 0.0964, Test Acc 0.9756, Drop Rate 0.1988 0.2005
# Epoch 12
# No Dropout : Train Loss 0.0355, Test Acc 0.9739
# Dropout    : Train Loss 0.0923, Test Acc 0.9767
# FBM Dropout: Train Loss 0.0908, Test Acc 0.9740, Drop Rate 0.1988 0.2002
# Epoch 13
# No Dropout : Train Loss 0.0356, Test Acc 0.9724
# Dropout    : Train Loss 0.0868, Test Acc 0.9783
# FBM Dropout: Train Loss 0.0904, Test Acc 0.9769, Drop Rate 0.1989 0.2007
# Epoch 14
# No Dropout : Train Loss 0.0312, Test Acc 0.9788
# Dropout    : Train Loss 0.0839, Test Acc 0.9749
# FBM Dropout: Train Loss 0.0887, Test Acc 0.9750, Drop Rate 0.1990 0.2004
# Epoch 15
# No Dropout : Train Loss 0.0298, Test Acc 0.9729
# Dropout    : Train Loss 0.0827, Test Acc 0.9712
# FBM Dropout: Train Loss 0.0835, Test Acc 0.9739, Drop Rate 0.1989 0.2009
# Epoch 16
# No Dropout : Train Loss 0.0284, Test Acc 0.9758
# Dropout    : Train Loss 0.0774, Test Acc 0.9763
# FBM Dropout: Train Loss 0.0824, Test Acc 0.9760, Drop Rate 0.1989 0.2014
# Epoch 17
# No Dropout : Train Loss 0.0272, Test Acc 0.9793
# Dropout    : Train Loss 0.0795, Test Acc 0.9747
# FBM Dropout: Train Loss 0.0801, Test Acc 0.9760, Drop Rate 0.1989 0.2012
# Epoch 18
# No Dropout : Train Loss 0.0257, Test Acc 0.9761
# Dropout    : Train Loss 0.0750, Test Acc 0.9759
# FBM Dropout: Train Loss 0.0762, Test Acc 0.9757, Drop Rate 0.1989 0.2014
# Epoch 19
# No Dropout : Train Loss 0.0234, Test Acc 0.9758
# Dropout    : Train Loss 0.0712, Test Acc 0.9741
# FBM Dropout: Train Loss 0.0758, Test Acc 0.9785, Drop Rate 0.1990 0.2015
# Epoch 20
# No Dropout : Train Loss 0.0232, Test Acc 0.9785
# Dropout    : Train Loss 0.0726, Test Acc 0.9790
# FBM Dropout: Train Loss 0.0763, Test Acc 0.9790, Drop Rate 0.1991 0.2014
# Epoch 21
# No Dropout : Train Loss 0.0238, Test Acc 0.9738
# Dropout    : Train Loss 0.0686, Test Acc 0.9730
# FBM Dropout: Train Loss 0.0669, Test Acc 0.9784, Drop Rate 0.1990 0.2013
# Epoch 22
# No Dropout : Train Loss 0.0192, Test Acc 0.9729
# Dropout    : Train Loss 0.0688, Test Acc 0.9777
# FBM Dropout: Train Loss 0.0712, Test Acc 0.9786, Drop Rate 0.1991 0.2011
# Epoch 23
# No Dropout : Train Loss 0.0212, Test Acc 0.9778
# Dropout    : Train Loss 0.0670, Test Acc 0.9766
# FBM Dropout: Train Loss 0.0689, Test Acc 0.9792, Drop Rate 0.1992 0.2009
# Epoch 24
# No Dropout : Train Loss 0.0177, Test Acc 0.9784
# Dropout    : Train Loss 0.0658, Test Acc 0.9817
# FBM Dropout: Train Loss 0.0667, Test Acc 0.9795, Drop Rate 0.1991 0.2009
# Epoch 25
# No Dropout : Train Loss 0.0213, Test Acc 0.9787
# Dropout    : Train Loss 0.0673, Test Acc 0.9769
# FBM Dropout: Train Loss 0.0671, Test Acc 0.9802, Drop Rate 0.1989 0.2010
# Epoch 26
# No Dropout : Train Loss 0.0176, Test Acc 0.9793
# Dropout    : Train Loss 0.0622, Test Acc 0.9790
# FBM Dropout: Train Loss 0.0650, Test Acc 0.9737, Drop Rate 0.1990 0.2012
# Epoch 27
# No Dropout : Train Loss 0.0182, Test Acc 0.9749
# Dropout    : Train Loss 0.0619, Test Acc 0.9766
# FBM Dropout: Train Loss 0.0649, Test Acc 0.9781, Drop Rate 0.1990 0.2014
# Epoch 28
# No Dropout : Train Loss 0.0182, Test Acc 0.9767
# Dropout    : Train Loss 0.0658, Test Acc 0.9770
# FBM Dropout: Train Loss 0.0640, Test Acc 0.9765, Drop Rate 0.1989 0.2016
# Epoch 29
# No Dropout : Train Loss 0.0158, Test Acc 0.9756
# Dropout    : Train Loss 0.0596, Test Acc 0.9780
# FBM Dropout: Train Loss 0.0636, Test Acc 0.9800, Drop Rate 0.1988 0.2016
# Epoch 30
# No Dropout : Train Loss 0.0192, Test Acc 0.9781
# Dropout    : Train Loss 0.0624, Test Acc 0.9780
# FBM Dropout: Train Loss 0.0605, Test Acc 0.9800, Drop Rate 0.1989 0.2015
# Epoch 31
# No Dropout : Train Loss 0.0167, Test Acc 0.9779
# Dropout    : Train Loss 0.0578, Test Acc 0.9791
# FBM Dropout: Train Loss 0.0586, Test Acc 0.9792, Drop Rate 0.1989 0.2016
# Epoch 32
# No Dropout : Train Loss 0.0168, Test Acc 0.9778
# Dropout    : Train Loss 0.0564, Test Acc 0.9801
# FBM Dropout: Train Loss 0.0605, Test Acc 0.9794, Drop Rate 0.1991 0.2016
# Epoch 33
# No Dropout : Train Loss 0.0151, Test Acc 0.9792
# Dropout    : Train Loss 0.0586, Test Acc 0.9800
# FBM Dropout: Train Loss 0.0586, Test Acc 0.9804, Drop Rate 0.1992 0.2016
# Epoch 34
# No Dropout : Train Loss 0.0147, Test Acc 0.9779
# Dropout    : Train Loss 0.0567, Test Acc 0.9760
# FBM Dropout: Train Loss 0.0602, Test Acc 0.9785, Drop Rate 0.1993 0.2015
# Epoch 35
# No Dropout : Train Loss 0.0168, Test Acc 0.9754
# Dropout    : Train Loss 0.0571, Test Acc 0.9800
# FBM Dropout: Train Loss 0.0521, Test Acc 0.9737, Drop Rate 0.1991 0.2014
# Epoch 36
# No Dropout : Train Loss 0.0159, Test Acc 0.9780
# Dropout    : Train Loss 0.0550, Test Acc 0.9789
# FBM Dropout: Train Loss 0.0526, Test Acc 0.9803, Drop Rate 0.1990 0.2016
# Epoch 37
# No Dropout : Train Loss 0.0132, Test Acc 0.9775
# Dropout    : Train Loss 0.0577, Test Acc 0.9811
# FBM Dropout: Train Loss 0.0571, Test Acc 0.9762, Drop Rate 0.1991 0.2017
# Epoch 38
# No Dropout : Train Loss 0.0144, Test Acc 0.9811
# Dropout    : Train Loss 0.0537, Test Acc 0.9797
# FBM Dropout: Train Loss 0.0529, Test Acc 0.9790, Drop Rate 0.1992 0.2015
# Epoch 39
# No Dropout : Train Loss 0.0139, Test Acc 0.9754
# Dropout    : Train Loss 0.0552, Test Acc 0.9793
# FBM Dropout: Train Loss 0.0541, Test Acc 0.9803, Drop Rate 0.1992 0.2015
# Epoch 40
# No Dropout : Train Loss 0.0167, Test Acc 0.9797
# Dropout    : Train Loss 0.0495, Test Acc 0.9779
# FBM Dropout: Train Loss 0.0539, Test Acc 0.9769, Drop Rate 0.1992 0.2015
# Epoch 41
# No Dropout : Train Loss 0.0099, Test Acc 0.9817
# Dropout    : Train Loss 0.0555, Test Acc 0.9786
# FBM Dropout: Train Loss 0.0488, Test Acc 0.9783, Drop Rate 0.1991 0.2014
# Epoch 42
# No Dropout : Train Loss 0.0154, Test Acc 0.9765
# Dropout    : Train Loss 0.0496, Test Acc 0.9818
# FBM Dropout: Train Loss 0.0530, Test Acc 0.9810, Drop Rate 0.1992 0.2014
# Epoch 43
# No Dropout : Train Loss 0.0124, Test Acc 0.9775
# Dropout    : Train Loss 0.0535, Test Acc 0.9769
# FBM Dropout: Train Loss 0.0509, Test Acc 0.9811, Drop Rate 0.1991 0.2014
# Epoch 44
# No Dropout : Train Loss 0.0151, Test Acc 0.9798
# Dropout    : Train Loss 0.0501, Test Acc 0.9799
# FBM Dropout: Train Loss 0.0523, Test Acc 0.9778, Drop Rate 0.1990 0.2013
# Epoch 45
# No Dropout : Train Loss 0.0121, Test Acc 0.9742
# Dropout    : Train Loss 0.0494, Test Acc 0.9787
# FBM Dropout: Train Loss 0.0518, Test Acc 0.9793, Drop Rate 0.1989 0.2012
# Epoch 46
# No Dropout : Train Loss 0.0111, Test Acc 0.9739
# Dropout    : Train Loss 0.0493, Test Acc 0.9805
# FBM Dropout: Train Loss 0.0485, Test Acc 0.9810, Drop Rate 0.1988 0.2013
# Epoch 47
# No Dropout : Train Loss 0.0127, Test Acc 0.9803
# Dropout    : Train Loss 0.0486, Test Acc 0.9803
# FBM Dropout: Train Loss 0.0550, Test Acc 0.9807, Drop Rate 0.1989 0.2014
# Epoch 48
# No Dropout : Train Loss 0.0105, Test Acc 0.9775
# Dropout    : Train Loss 0.0474, Test Acc 0.9774
# FBM Dropout: Train Loss 0.0479, Test Acc 0.9729, Drop Rate 0.1989 0.2013
# Epoch 49
# No Dropout : Train Loss 0.0136, Test Acc 0.9797
# Dropout    : Train Loss 0.0488, Test Acc 0.9799
# FBM Dropout: Train Loss 0.0503, Test Acc 0.9792, Drop Rate 0.1989 0.2013

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(results['train loss']['no dropout'], label='No Dropout')
plt.plot(results['train loss']['dropout'], label='Dropout')
plt.plot(results['train loss']['fbm dropout'], label='FBM Dropout')
plt.title('Train Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(results['test acc']['no dropout'], label='No Dropout')
plt.plot(results['test acc']['dropout'], label='Dropout')
plt.plot(results['test acc']['fbm dropout'], label='FBM Dropout')
plt.title('Test Accuracy')
plt.legend()
plt.show()
